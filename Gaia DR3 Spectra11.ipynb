# %%
import webbrowser

webbrowser.open('http://cdn.gea.esac.esa.int/Gaia/gdr3/gaia_source/')

webbrowser.open('http://cdn.gea.esac.esa.int/Gaia/gdr3/Astrophysical_parameters/astrophysical_parameters/')

webbrowser.open('http://cdn.gea.esac.esa.int/Gaia/gdr3/')

webbrowser.open("https://gea.esac.esa.int/archive/")

webbrowser.open('https://www.cosmos.esa.int/web/gaia-users/archive/datalink-products')

#webbrowser.open('https://www.cosmos.esa.int/web/gaia/gaiaxpy')

webbrowser.open('https://gaia-dpci.github.io/GaiaXPy-website/')

# %%
import pandas as pd
import numpy as np
import scipy as sp

import starcolorindexSpT 

from astropy.coordinates import SkyCoord
import astropy.units as u

from astroquery.gaia import Gaia
from astroquery.simbad import Simbad 

import astropy.coordinates as coord

import pyvo as vo

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

import plotly.express as px

# %%
import astropy
import astroquery
import astroquery
import pyvo
import matplotlib
import plotly

print("pandas " + str(pd.__version__))
print("numpy " + str(np.__version__))
print("scipy " + str(sp.__version__))
print("astropy " + str(astropy.__version__))
print("astroquery " + str(astroquery.__version__))
print("pyvo " + str(pyvo.__version__))
print("matplotlib " + str(matplotlib.__version__))
print("plotly " + str(plotly.__version__))

print("\n")
# !python --version

print("\n")
# !jupyter --version

# %%
Ipython_default = plt.rcParams.copy()

# reset rcParams
#plt.rcParams.update(Ipython_default)

#plt.style.use('dark_background')

#print("Backup default plot background. \nSet Dark background.")

# reset rcParams

#plt.rcParams.update(Ipython_default)

#plt.style.use('dark_background')

# %%
f1  = pd.read_csv("Data/r2_000000-003111.csv")
f2  = pd.read_csv("Data/r2_003112-005263.csv")
f3  = pd.read_csv("Data/r2_005264-006601.csv") # New
f4  = pd.read_csv("Data/r2_006602-007952.csv") # New
f5  = pd.read_csv("Data/r2_007953-010234.csv") # New
f50 = pd.read_csv("Data/r2_010235-012597.csv") # New
f51 = pd.read_csv("Data/r2_012598-014045.csv") # New
f52 = pd.read_csv("Data/r2_014046-015369.csv") # New
f16 = pd.read_csv("Data/r2_015370-016240.csv")

# %%
f42 = pd.read_csv("Data/r2_050131-050376.csv")
f41 = pd.read_csv("Data/r2_060161-060361.csv")
f40 = pd.read_csv("Data/r2_071196-073887.csv")
f30 = pd.read_csv("Data/r2_080128-082787.csv")
f29 = pd.read_csv("Data/r2_090621-093880.csv")

# %%
f6  =  pd.read_csv("Data/r2_100752-101392.csv")
f10 =  pd.read_csv("Data/r2_200212-200517.csv")

# %%
f53 = pd.read_csv("Data/r2_248986-249150.csv") # New
f54 = pd.read_csv("Data/r2_249151-249315.csv") # New
f55 = pd.read_csv("Data/r2_249316-249570.csv") # New
f23 = pd.read_csv("Data/r2_249571-249860.csv")
f22 = pd.read_csv("Data/r2_249861-249951.csv")
f19 = pd.read_csv("Data/r2_249952-250048.csv")
f18 = pd.read_csv("Data/r2_250049-250171.csv")
f20 = pd.read_csv("Data/r2_250172-250299.csv")
f21 = pd.read_csv("Data/r2_250300-250414.csv")
f56 = pd.read_csv("Data/r2_250415-250504.csv") # New
f57 = pd.read_csv("Data/r2_250505-250614.csv") # New

# %%
f11 = pd.read_csv("Data/r2_302249-303999.csv")
f17 = pd.read_csv("Data/r2_350313-350776.csv")
f8  = pd.read_csv("Data/r2_401060-402397.csv")
f61 = pd.read_csv("Data/r2_450182-453970.csv") # New
f65 = pd.read_csv("Data/r2_499565-500276.csv") # New
f9  = pd.read_csv("Data/r2_500277-501155.csv")
f66 = pd.read_csv("Data/r2_501156-502152.csv") # New
f60 = pd.read_csv("Data/r2_551056-553777.csv") # New
f13 = pd.read_csv("Data/r2_600127-600319.csv")
f59 = pd.read_csv("Data/r2_650113-650281.csv") # New
f14 = pd.read_csv("Data/r2_700446-700929.csv")
f58 = pd.read_csv("Data/r2_750557-752583.csv") # New
f64 = pd.read_csv("Data/r2_784993-785417.csv") # New
f63 = pd.read_csv("Data/r2_785418-786096.csv") # New
f62 = pd.read_csv("Data/r2_786097-786431.csv") # New

# %%
print("Files in Ra/Dec Ascending Order\n")


# Ra: 7.68   Dec: 68.89
print("   Ra: " + str(round(f41['ra'].mean(),2)) + "    Dec: " +  str(round(f41['dec'].mean(),2)) +
                                 "   l: " + str(round(f41['l'].mean(),2)) + "  b: " +  str(round(f41['b'].mean(),2)) +
                                  "     Class O: " + str(f41[f41['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f41[f41['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f41[f41['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f41.shape[0])) 

# Ra: 33.28   Dec: 22.54 
print("   Ra: " + str(round(f50['ra'].mean(),2)) + "   Dec: " +  str(round(f50['dec'].mean(),2)) +
                                 "   l: " + str(round(f50['l'].mean(),2)) + "  b: " +  str(round(f50['b'].mean(),2)) +
                                  "   Class O: " + str(f50[f50['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f50[f50['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f50[f50['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f50.shape[0])) 

# Ra: 41.57   Dec: 19.78
print("   Ra: " + str(round(f5['ra'].mean(),2)) + "   Dec: " +  str(round(f5['dec'].mean(),2)) +
                                   "   l: " + str(round(f5['l'].mean(),2)) + "  b: " +  str(round(f5['b'].mean(),2)) +
                                   "   Class O: " + str(f5[f5['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f5[f5['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f5[f5['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f5.shape[0])) 

# Ra: 42.27   Dec: 31.02
print("   Ra: " + str(round(f52['ra'].mean(),2)) + "   Dec: " +  str(round(f52['dec'].mean(),2)) +
                                 "   l: " + str(round(f52['l'].mean(),2)) + "  b: " +  str(round(f52['b'].mean(),2)) +
                                  "   Class O: " + str(f52[f52['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f52[f52['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f52[f52['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f52.shape[0])) 

#  Ra: 45.06   Dec: 8.04
print("   Ra: " + str(round(f1['ra'].mean(),2)) + "   Dec: " +  str(round(f1['dec'].mean(),2)) +
                                   "    l: " + str(round(f1['l'].mean(),2)) + "   b: " +  str(round(f1['b'].mean(),2)) +
                                   "   Class O: " + str(f1[f1['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f1[f1['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f1[f1['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f1.shape[0])) 

# Ra: 45.12   Dec: 35.47
print("   Ra: " + str(round(f16['ra'].mean(),2)) + "   Dec: " +  str(round(f16['dec'].mean(),2)) +
                                 "   l: " + str(round(f16['l'].mean(),2)) + "  b: " +  str(round(f16['b'].mean(),2)) +
                                  "   Class O: " + str(f16[f16['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f16[f16['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f16[f16['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f16.shape[0])) 

# 48.17   Dec: 27.49
print("   Ra: " + str(round(f51['ra'].mean(),2)) + "   Dec: " +  str(round(f51['dec'].mean(),2)) +
                                 "   l: " + str(round(f51['l'].mean(),2)) + "   b: " +  str(round(f51['b'].mean(),2)) +
                                  "   Class O: " + str(f51[f51['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f51[f51['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f51[f51['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f51.shape[0])) 

# Ra: 50.48   Dec: 51.11
print("   Ra: " + str(round(f42['ra'].mean(),2)) + "   Dec: " +  str(round(f42['dec'].mean(),2)) +
                                 "   l: " + str(round(f42['l'].mean(),2)) + "  b: " +  str(round(f42['b'].mean(),2)) +
                                  "    Class O: " + str(f42[f42['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f42[f42['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f42[f42['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f42.shape[0])) 

# Ra: 52.25   Dec: 14.87
print("   Ra: " + str(round(f2['ra'].mean(),2)) + "   Dec: " +  str(round(f2['dec'].mean(),2)) +
                                   "   l: " + str(round(f2['l'].mean(),2)) + "  b: " +  str(round(f2['b'].mean(),2)) +
                                   "   Class O: " + str(f2[f2['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f2[f2['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f2[f2['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f2.shape[0])) 

# Ra: 54.39   Dec: 22.97 
print("   Ra: " + str(round(f4['ra'].mean(),2)) + "   Dec: " +  str(round(f4['dec'].mean(),2)) +
                                   "   l: " + str(round(f4['l'].mean(),2)) + "  b: " +  str(round(f4['b'].mean(),2)) +
                                   "   Class O: " + str(f4[f4['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f4[f4['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f4[f4['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f4.shape[0])) 

# Ra: 58.84   Dec: -37.61
print("   Ra: " + str(round(f60['ra'].mean(),2)) + "   Dec: " +  str(round(f60['dec'].mean(),2)) +
                                 "  l: " + str(round(f60['l'].mean(),2)) + "  b: " +  str(round(f60['b'].mean(),2)) +
                                  "   Class O: " + str(f60[f60['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f60[f60['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f60[f60['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f60.shape[0])) 

# Ra: 58.95   Dec: 19.61
print("   Ra: " + str(round(f3['ra'].mean(),2)) + "   Dec: " +  str(round(f3['dec'].mean(),2)) +
                                   "   l: " + str(round(f3['l'].mean(),2)) + "  b: " +  str(round(f3['b'].mean(),2)) +
                                   "    Class O: " + str(f3[f3['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f3[f3['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f3[f3['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f3.shape[0])) 

# Ra: 96.59   Dec: -69.01
print("   Ra: " + str(round(f13['ra'].mean(),2)) + "   Dec: " +  str(round(f13['dec'].mean(),2)) +
                                 "  l: " + str(round(f13['l'].mean(),2)) + "  b: " +  str(round(f13['b'].mean(),2)) +
                                  "    Class O: " + str(f13[f13['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f13[f13['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f13[f13['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f13.shape[0])) 

# Ra: 105.86  Dec: 31.11
print("   Ra: " + str(round(f6['ra'].mean(),2)) + "  Dec: " +  str(round(f6['dec'].mean(),2)) +
                                 "   l: " + str(round(f6['l'].mean(),2)) + "  b: " +  str(round(f6['b'].mean(),2)) +
                                  "    Class O: " + str(f6[f6['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f6[f6['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f6[f6['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f6.shape[0])) 

# Ra: 118.52  Dec: -16.76
print("   Ra: " + str(round(f59['ra'].mean(),2)) + "  Dec: " +  str(round(f59['dec'].mean(),2)) +
                                 "  l: " + str(round(f59['l'].mean(),2)) + "  b: " +  str(round(f59['b'].mean(),2)) +
                                  "     Class O: " + str(f59[f59['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f59[f59['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f59[f59['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f59.shape[0])) 

# Ra: 118.7   Dec: -0.94
print("   Ra: " + str(round(f17['ra'].mean(),2)) + "   Dec: " +  str(round(f17['dec'].mean(),2)) +
                                 "   l: " + str(round(f17['l'].mean(),2)) + "  b: " +  str(round(f17['b'].mean(),2)) +
                                  "    Class O: " + str(f17[f17['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f17[f17['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f17[f17['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f17.shape[0])) 

# Ra: 137.77  Dec: 31.29
print("   Ra: " + str(round(f30['ra'].mean(),2)) + "  Dec: " +  str(round(f30['dec'].mean(),2)) +
                                 "   l: " + str(round(f30['l'].mean(),2)) + "  b: " +  str(round(f30['b'].mean(),2)) +
                                  "    Class O: " + str(f30[f30['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f30[f30['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f30[f30['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f30.shape[0]))   

# Ra: 141.26  Dec: 20.1
print("   Ra: " + str(round(f40['ra'].mean(),2)) + "  Dec: " +  str(round(f40['dec'].mean(),2)) +
                                 "    l: " + str(round(f40['l'].mean(),2)) + "  b: " +  str(round(f40['b'].mean(),2)) +
                                  "    Class O: " + str(f40[f40['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f40[f40['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f40[f40['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f40.shape[0])) 

# Ra: 146.05  Dec: 42.14
print("   Ra: " + str(round(f29['ra'].mean(),2)) + "  Dec: " +  str(round(f29['dec'].mean(),2)) +
                                 "   l: " + str(round(f29['l'].mean(),2)) + "  b: " +  str(round(f29['b'].mean(),2)) +
                                  "    Class O: " + str(f29[f29['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f29[f29['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f29[f29['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f29.shape[0]))   

# Ra: 170.6   Dec: 19.0
print("   Ra: " + str(round(f61['ra'].mean(),2)) + "   Dec: " +  str(round(f61['dec'].mean(),2)) +
                                 "    l: " + str(round(f61['l'].mean(),2)) + "  b: " +  str(round(f61['b'].mean(),2)) +
                                  "    Class O: " + str(f61[f61['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f61[f61['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f61[f61['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "  Total: " + str(f61.shape[0])) 

# Ra: 172.61  Dec: -22.74
print("   Ra: " + str(round(f8['ra'].mean(),2)) + "  Dec: " +  str(round(f8['dec'].mean(),2)) +
                                 "  l: " + str(round(f8['l'].mean(),2)) + "  b: " +  str(round(f8['b'].mean(),2)) +
                                  "    Class O: " + str(f8[f8['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f8[f8['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f8[f8['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f8.shape[0])) 

# Ra: 203.9   Dec: -37.16
print("   Ra: " + str(round(f14['ra'].mean(),2)) + "   Dec: " +  str(round(f14['dec'].mean(),2)) +
                                 "  l: " + str(round(f14['l'].mean(),2)) + "  b: " +  str(round(f14['b'].mean(),2)) +
                                  "    Class O: " + str(f14[f14['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f14[f14['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f14[f14['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f14.shape[0])) 

# Ra: 238.3   Dec: 0.27
print("   Ra: " + str(round(f66['ra'].mean(),2)) + "   Dec: " +  str(round(f66['dec'].mean(),2)) +
                                 "    l: " + str(round(f66['l'].mean(),2)) + "   b: " +  str(round(f66['b'].mean(),2)) +
                                  "    Class O: " + str(f66[f66['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f66[f66['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f66[f66['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f66.shape[0])) 

# Ra: 239.72  Dec: -2.32
print("   Ra: " + str(round(f9['ra'].mean(),2)) + "  Dec: " +  str(round(f9['dec'].mean(),2)) +
                                 "   l: " + str(round(f9['l'].mean(),2)) + "   b: " +  str(round(f9['b'].mean(),2)) +
                                  "    Class O: " + str(f9[f9['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f9[f9['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f9[f9['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f9.shape[0])) 

# Ra: 244.71  Dec: -1.22
print("   Ra: " + str(round(f65['ra'].mean(),2)) + "  Dec: " +  str(round(f65['dec'].mean(),2)) +
                                 "   l: " + str(round(f65['l'].mean(),2)) + "   b: " +  str(round(f65['b'].mean(),2)) +
                                  "     Class O: " + str(f65[f65['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f65[f65['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f65[f65['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f65.shape[0])) 

# Ra: 308.11  Dec: -7.94
print("   Ra: " + str(round(f64['ra'].mean(),2)) + "  Dec: " +  str(round(f64['dec'].mean(),2)) +
                                 "   l: " + str(round(f64['l'].mean(),2)) + "   b: " +  str(round(f64['b'].mean(),2)) +
                                  "   Class O: " + str(f64[f64['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f64[f64['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f64[f64['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f64.shape[0]))


# Ra: 311.34  Dec: 60.4
print("   Ra: " + str(round(f55['ra'].mean(),2)) + "  Dec: " +  str(round(f55['dec'].mean(),2)) +
                                 "    l: " + str(round(f55['l'].mean(),2)) + "   b: " +  str(round(f55['b'].mean(),2)) +
                                  "    Class O: " + str(f55[f55['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f55[f55['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f55[f55['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f55.shape[0])) 

# Ra: 312.67  Dec: 14.89
print("   Ra: " + str(round(f10['ra'].mean(),2)) + "  Dec: " +  str(round(f10['dec'].mean(),2)) +
                                 "   l: " + str(round(f10['l'].mean(),2)) + "   b: " +  str(round(f10['b'].mean(),2)) +
                                  "   Class O: " + str(f10[f10['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f10[f10['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f10[f10['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f10.shape[0])) 

# Ra: 314.1   Dec: -2.73
print("   Ra: " + str(round(f62['ra'].mean(),2)) + "   Dec: " +  str(round(f62['dec'].mean(),2)) +
                                 "   l: " + str(round(f62['l'].mean(),2)) + "   b: " +  str(round(f62['b'].mean(),2)) +
                                  "   Class O: " + str(f62[f62['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f62[f62['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f62[f62['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f62.shape[0])) 

# Ra: 314.95  Dec: -5.74
print("   Ra: " + str(round(f63['ra'].mean(),2)) + "  Dec: " +  str(round(f63['dec'].mean(),2)) +
                                 "   l: " + str(round(f63['l'].mean(),2)) + "   b: " +  str(round(f63['b'].mean(),2)) +
                                  "   Class O: " + str(f63[f63['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f63[f63['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f63[f63['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f63.shape[0])) 

# Ra: 315.12  Dec: 62.87
print("   Ra: " + str(round(f23['ra'].mean(),2)) + "  Dec: " +  str(round(f23['dec'].mean(),2)) +
                                 "   l: " + str(round(f23['l'].mean(),2)) + "   b: " +  str(round(f23['b'].mean(),2)) +
                                  "    Class O: " + str(f23[f23['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f23[f23['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f23[f23['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f23.shape[0]))  

# Ra: 316.48  Dec: 58.59 
print("   Ra: " + str(round(f53['ra'].mean(),2)) + "  Dec: " +  str(round(f53['dec'].mean(),2)) +
                                 "   l: " + str(round(f53['l'].mean(),2)) + "   b: " +  str(round(f53['b'].mean(),2)) +
                                  "     Class O: " + str(f53[f53['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f53[f53['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f53[f53['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f53.shape[0])) 

# Ra: 320.31  Dec: 60.64
print("   Ra: " + str(round(f54['ra'].mean(),2)) + "  Dec: " +  str(round(f54['dec'].mean(),2)) +
                                 "   l: " + str(round(f54['l'].mean(),2)) + "   b: " +  str(round(f54['b'].mean(),2)) +
                                  "      Class O: " + str(f54[f54['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f54[f54['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f54[f54['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f54.shape[0])) 

# 327.94  Dec: 61.31 
print("   Ra: " + str(round(f57['ra'].mean(),2)) + "  Dec: " +  str(round(f57['dec'].mean(),2)) +
                                 "   l: " + str(round(f57['l'].mean(),2)) + "  b: " +  str(round(f57['b'].mean(),2)) +
                                  "     Class O: " + str(f57[f57['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f57[f57['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f57[f57['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f57.shape[0])) 

# Ra: 329.94  Dec: 60.2
print("   Ra: " + str(round(f56['ra'].mean(),2)) + "  Dec: " +  str(round(f56['dec'].mean(),2)) +
                                 "    l: " + str(round(f56['l'].mean(),2)) + "   b: " +  str(round(f56['b'].mean(),2)) +
                                  "     Class O: " + str(f56[f56['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f56[f56['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f56[f56['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f56.shape[0])) 

# Ra: 330.78  Dec: 57.49
print("   Ra: " + str(round(f19['ra'].mean(),2)) + "  Dec: " +  str(round(f19['dec'].mean(),2)) +
                                 "   l: " + str(round(f19['l'].mean(),2)) + "  b: " +  str(round(f19['b'].mean(),2)) +
                                  "      Class O: " + str(f19[f19['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "   Class B: " + str(f19[f19['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f19[f19['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f19.shape[0]))

# Ra: 331.75  Dec: 56.31
print("   Ra: " + str(round(f22['ra'].mean(),2)) + "  Dec: " +  str(round(f22['dec'].mean(),2)) +
                                 "   l: " + str(round(f22['l'].mean(),2)) + "  b: " +  str(round(f22['b'].mean(),2)) +
                                  "     Class O: " + str(f22[f22['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f22[f22['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f22[f22['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f22.shape[0]))

# Ra: 332.7   Dec: 60.23
print("   Ra: " + str(round(f21['ra'].mean(),2)) + "   Dec: " +  str(round(f21['dec'].mean(),2)) +
                                 "   l: " + str(round(f21['l'].mean(),2)) + "  b: " +  str(round(f21['b'].mean(),2)) +
                                  "     Class O: " + str(f21[f21['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "    Class B: " + str(f21[f21['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f21[f21['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f21.shape[0]))

# Ra: 333.68  Dec: -1.62
print("   Ra: " + str(round(f11['ra'].mean(),2)) + "  Dec: " +  str(round(f11['dec'].mean(),2)) +
                                 "   l: " + str(round(f11['l'].mean(),2)) + "    b: " +  str(round(f11['b'].mean(),2)) +
                                  "   Class O: " + str(f11[f11['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f11[f11['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f11[f11['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f11.shape[0])) 

# Ra: 334.28  Dec: 58.85
print("   Ra: " + str(round(f18['ra'].mean(),2)) + "  Dec: " +  str(round(f18['dec'].mean(),2)) +
                                 "   l: " + str(round(f18['l'].mean(),2)) + "  b: " +  str(round(f18['b'].mean(),2)) +
                                  "     Class O: " + str(f18[f18['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "   Class B: " + str(f18[f18['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f18[f18['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f18.shape[0]))

# Ra: 336.7    Dec: -30.2 
print("   Ra: " + str(round(f58['ra'].mean(),2)) + "   Dec: " +  str(round(f58['dec'].mean(),2)) +
                                 "   l: " + str(round(f58['l'].mean(),2)) + "   b: " +  str(round(f58['b'].mean(),2)) +
                                  "    Class O: " + str(f58[f58['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "     Class B: " + str(f58[f58['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "    Class M: " + str(f58[f58['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f58.shape[0])) 

# Ra: 337.51  Dec: 60.36
print("   Ra: " + str(round(f20['ra'].mean(),2)) + "  Dec: " +  str(round(f20['dec'].mean(),2)) +
                                 "   l: " + str(round(f20['l'].mean(),2)) + "   b: " +  str(round(f20['b'].mean(),2)) +
                                  "     Class O: " + str(f20[f20['spectraltype_esphs'] == "O"].shape[0]) + 
                                   "   Class B: " + str(f20[f20['spectraltype_esphs'] == "B"].shape[0]) + 
                                   "   Class M: " + str(f20[f20['spectraltype_esphs'] == "M"].shape[0]) + 
                                   "   Total: " + str(f20.shape[0]))
# Out:
# Files in Ra/Dec Ascending Order
#
#    Ra: 7.68    Dec: 68.89   l: 121.09  b: 6.12     Class O: 641    Class B: 1724   Class M: 4380   Total: 55899
#    Ra: 33.28   Dec: 22.54   l: 146.28  b: -36.32   Class O: 116    Class B: 557    Class M: 10161  Total: 133117
#    Ra: 41.57   Dec: 19.78   l: 155.74  b: -35.29   Class O: 135    Class B: 590    Class M: 9357   Total: 127416
#    Ra: 42.27   Dec: 31.02   l: 150.53  b: -25.32   Class O: 134    Class B: 559    Class M: 6242   Total: 122009
#    Ra: 45.06   Dec: 8.04    l: 168.9   b: -42.81   Class O: 123    Class B: 590    Class M: 11438  Total: 125644
#    Ra: 45.12   Dec: 35.47   l: 150.54  b: -20.35   Class O: 128    Class B: 586    Class M: 4660   Total: 120117
#    Ra: 48.17   Dec: 27.49   l: 157.5   b: -25.66   Class O: 191    Class B: 627    Class M: 6627   Total: 115970
#    Ra: 50.48   Dec: 51.11   l: 145.57  b: -4.97    Class O: 465    Class B: 2797   Class M: 2616   Total: 78452
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 8))

plt.subplot(111)
image1 = plt.scatter(f1['l'], f1['b'], label="f1 " + str(f1.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image2 = plt.scatter(f2['l'], f2['b'], label="f2 " + str(f2.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image3 = plt.scatter(f3['l'], f3['b'], label="f3 " + str(f3.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image4 = plt.scatter(f4['l'], f4['b'], label="f4 " + str(f4.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image5 = plt.scatter(f5['l'], f5['b'], label="f5 " + str(f5.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image6 = plt.scatter(f6['l'], f6['b'], label="f6 " + str(f6.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image8 = plt.scatter(f8['l'], f8['b'], label="f8 " + str(f8.shape[0]), marker='.', linewidth=0,
            c='magenta',edgecolor='k',cmap="jet_r")
image9 = plt.scatter(f9['l'], f9['b'], label="f9 " + str(f9.shape[0]), marker='.', linewidth=0,
            c='orange',edgecolor='k',cmap="jet_r")
image10 = plt.scatter(f10['l'], f10['b'], label="f10 " + str(f10.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image11 = plt.scatter(f11['l'], f11['b'], label="f11 " + str(f11.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image13 = plt.scatter(f13['l'], f13['b'], label="f13 " + str(f13.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image14 = plt.scatter(f14['l'], f14['b'], label="f14 " + str(f14.shape[0]), marker='.', linewidth=0,
            c='magenta',edgecolor='k',cmap="jet_r")
image16 = plt.scatter(f16['l'], f16['b'], label="f16 " + str(f16.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image17 = plt.scatter(f17['l'], f17['b'], label="f17 " + str(f17.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image18 = plt.scatter(f18['l'], f18['b'], label="f18 " + str(f18.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image19 = plt.scatter(f19['l'], f19['b'], label="f19 " + str(f19.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image20 = plt.scatter(f20['l'], f20['b'], label="f20 " + str(f20.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image21 = plt.scatter(f21['l'], f21['b'], label="f21 " + str(f21.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image22 = plt.scatter(f22['l'], f22['b'], label="f22 " + str(f22.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image23 = plt.scatter(f23['l'], f23['b'], label="f23 " + str(f23.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image29 = plt.scatter(f29['l'], f29['b'], label="f29 " + str(f29.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image30 = plt.scatter(f30['l'], f30['b'], label="f30 " + str(f30.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image40 = plt.scatter(f40['l'], f40['b'], label="f40 " + str(f40.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image41 = plt.scatter(f41['l'], f41['b'], label="f41 " + str(f41.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image42 = plt.scatter(f42['l'], f42['b'], label="f42 " + str(f42.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image50 = plt.scatter(f50['l'], f50['b'], label="f50 " + str(f50.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image51 = plt.scatter(f51['l'], f51['b'], label="f51 " + str(f51.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image52 = plt.scatter(f52['l'], f52['b'], label="f52 " + str(f52.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image53 = plt.scatter(f53['l'], f53['b'], label="f53 " + str(f53.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image54 = plt.scatter(f54['l'], f54['b'], label="f54 " + str(f54.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image55 = plt.scatter(f55['l'], f55['b'], label="f55 " + str(f55.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image56 = plt.scatter(f56['l'], f56['b'], label="f56 " + str(f56.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image57 = plt.scatter(f57['l'], f57['b'], label="f57 " + str(f57.shape[0]), marker='.', linewidth=0,
            c='yellow',edgecolor='k',cmap="jet_r")
image58 = plt.scatter(f58['l'], f58['b'], label="f58 " + str(f58.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image59 = plt.scatter(f59['l'], f59['b'], label="f59 " + str(f58.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image60 = plt.scatter(f60['l'], f60['b'], label="f60 " + str(f60.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
image61 = plt.scatter(f61['l'], f61['b'], label="f61 " + str(f61.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image62 = plt.scatter(f62['l'], f62['b'], label="f62 " + str(f62.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image63 = plt.scatter(f63['l'], f63['b'], label="f63 " + str(f63.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image64 = plt.scatter(f64['l'], f64['b'], label="f64 " + str(f64.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image65 = plt.scatter(f65['l'], f65['b'], label="f65 " + str(f65.shape[0]), marker='.', linewidth=0,
            c='orange',edgecolor='k',cmap="jet_r")
image66 = plt.scatter(f66['l'], f66['b'], label="f66 " + str(f66.shape[0]), marker='.', linewidth=0,
            c='orange',edgecolor='k',cmap="jet_r")

fsize = 10

ax = plt.gca()
#plt.gca().invert_yaxis()
plt.xlabel('l', fontsize=fsize)
plt.ylabel('b', fontsize=fsize)
plt.xticks(size = fsize)
plt.yticks(size = fsize)
#plt.grid()
plt.title('Gaia DR3', fontsize=10)
plt.legend(fontsize=15)
#plt.text(f1['l'].mean(), f1['b'].mean(), "f1", fontsize=12, color="red")
#plt.text(f2['l'].mean(), f2['b'].mean(), "f2", fontsize=20, color="red")
plt.text(f3['l'].mean(), f3['b'].mean(), "    f1,f2,3,4,5", fontsize=fsize, color="red")
#plt.text(f4['l'].mean(), f4['b'].mean(), "f4", fontsize=20, color="red")
#plt.text(f5['l'].mean(), f5['b'].mean(), "f5", fontsize=20, color="red")
plt.text(f6['l'].mean(), f6['b'].mean(), "  f6", fontsize=fsize, color="red")
plt.text(f8['l'].mean(), f8['b'].mean(), "f8", fontsize=fsize, color="k")
plt.text(f9['l'].median(), f9['b'].median(), " f9,65,66", fontsize=fsize, color="red")
plt.text(f10['l'].mean(), f10['b'].mean(), " f10", fontsize=fsize, color="red")
plt.text(f11['l'].mean(), f11['b'].mean(), "f11", fontsize=fsize, color="red")
plt.text(f13['l'].mean(), f13['b'].mean(), "  f13", fontsize=fsize, color="red")
plt.text(f14['l'].mean(), f14['b'].mean(), "  f14", fontsize=fsize, color="k")
plt.text(f16['l'].mean(), f16['b'].mean(), "f16", fontsize=fsize, color="red")
plt.text(f17['l'].mean(), f17['b'].mean(), "  f17", fontsize=fsize, color="red")
#plt.text(f18['l'].mean(), f18['b'].mean(), "f18", fontsize=20, color="red")
plt.text(f19['l'].mean(), f19['b'].mean(), "f18,19,20,21,22", fontsize=fsize, color="red")
#plt.text(f23['l'].mean(), f23['b'].mean(), "f23", fontsize=20, color="red")
plt.text(f29['l'].mean(), f29['b'].mean(), "   f29", fontsize=fsize, color="red")
plt.text(f30['l'].mean(), f30['b'].mean(), "f30", fontsize=fsize, color="red")
plt.text(f40['l'].mean(), f40['b'].mean(), "   f40", fontsize=fsize, color="red")
#plt.text(f41['l'].mean(), f41['b'].mean(), "f41", fontsize=20, color="red")
plt.text(f42['l'].mean(), f42['b'].mean(), "f41, 42", fontsize=fsize, color="red")
plt.text(f50['l'].mean(), f50['b'].mean(), "f50,51,52", fontsize=fsize, color="red")
#plt.text(f51['l'].mean(), f51['b'].mean(), "f51", fontsize=20, color="red")
#plt.text(f52['l'].mean(), f52['b'].mean(), "f52", fontsize=20, color="red")
plt.text(f53['l'].mean(), f53['b'].mean(), "f23,53,54,55,56,57", fontsize=fsize, color="red")
#plt.text(f54['l'].mean(), f54['b'].mean(), "f54", fontsize=20, color="red")
#plt.text(f55['l'].mean(), f55['b'].mean(), "f55", fontsize=20, color="red")
#plt.text(f56['l'].mean(), f56['b'].mean(), "f56", fontsize=20, color="red")
#plt.text(f57['l'].mean(), f57['b'].mean(), "f57", fontsize=20, color="red")
plt.text(f58['l'].mean(), f58['b'].mean(), "f58", fontsize=fsize, color="red")
plt.text(f59['l'].mean(), f59['b'].mean(), "f59", fontsize=fsize, color="red")
plt.text(f60['l'].mean(), f60['b'].mean(), "f60", fontsize=fsize, color="red")
plt.text(f61['l'].mean(), f61['b'].mean(), "f61", fontsize=fsize, color="red")
plt.text(f62['l'].mean(), f62['b'].mean(), "f62,63,64", fontsize=fsize, color="red")
#plt.text(f63['l'].mean(), f63['b'].mean(), "f63", fontsize=fsize, color="red")
#plt.text(f64['l'].mean(), f64['b'].mean(), "f64", fontsize=fsize, color="red")
#plt.text(f65['l'].median(), f65['b'].median(), "f65", fontsize=fsize, color="red")
#plt.text(f66['l'].median(), f66['b'].median(), "f66", fontsize=fsize, color="red")

plt.legend(bbox_to_anchor=(1.05, 0.0), loc='lower right', fontsize=8)
plt.show()

# %%
df_all = pd.concat([f1, f2, f3, f5, f4, f6, f8, f9, 
                f10, f11, f13, f14, f16, f17, f18, f19,
                f20, f21, f22, f23, f29, f30, f40, f41, f42, 
                f50, f51, f52, f53, f54, f55, f56, f57, f58, f59,
                f60, f61, f62, f63, f64, f65, f66], ignore_index=True, sort=False)
print("df_all: " + str(df_all.shape[0]))

df_OB = df_all[(df_all['spectraltype_esphs'] == "O") | (df_all['spectraltype_esphs'] == "B")] 
print("df_OB: " + str(df_OB.shape[0]))
# Out:
# df_all: 4015167
# df_OB: 64749

# %%
df1 = df_all

#df1 = df_OB

df1.shape[0]
# Out:
# 4015167

# %%
import numpy as np
import scipy as sp
import starcolorindexSpT 

df1['SpT2'] = df1.apply(lambda row: starcolorindexSpT.subclass[round(row.bp_rp, 2)], axis=1)

# %%
df1['SpT2_dereddened'] = df1.apply(lambda row: starcolorindexSpT.subclass[round((row.bp_rp - row.ebpminrp_gspphot), 2)], axis=1)

# %%
import numpy as np

conditions = [
    (df1['logg_gspphot'].astype(float) > 4.20),
    ((df1['logg_gspphot'].astype(float) <= 4.20) & (df1['logg_gspphot'].astype(float) > 3.90)),
    ((df1['logg_gspphot'].astype(float) <= 3.90) & (df1['logg_gspphot'].astype(float) > 3.60)),
    ((df1['logg_gspphot'].astype(float) < 2.55) & (df1['logg_gspphot'].astype(float) > 2.35)),
    (df1['logg_gspphot'].astype(float) <= 3.60),
    (df1['logg_gspphot'].isna())
]

values = ['main_sequence', 'turnoff', 'subgiants', 'red_clump', 'red_giants', 'null']

df1['Star_Type'] = np.select(conditions, values)

# %%
import scipy as sp

unique_star_type = sp.unique(df1['Star_Type'].astype(str))

for i in unique_star_type:
    print(str(i) + ": " + str(df1[df1['Star_Type'] == i].shape[0]))
# Out:
# main_sequence: 2921633
# null: 382801
# red_clump: 14235
# red_giants: 198750
# subgiants: 148622
# turnoff: 349126

# %%
"""

main_sequence: 2921633
null: 382801
red_clump: 14235
red_giants: 198750
subgiants: 148622
turnoff: 349126

""";

# %%
unique_classlabel = sp.unique(df1['classlabel_espels'].astype(str))

for i in unique_classlabel:
    print(str(i) + ": " + str(df1[df1['classlabel_espels'] == i].shape[0]))
# Out:
# HerbigStar: 90
# PlanetaryNebula: 2
# RedDwarfEmStar: 28
# TTauri: 350
# beStar: 182
# nan: 0
# wN: 5

# %%
"""

HHerbigStar: 90
PlanetaryNebula: 2
RedDwarfEmStar: 28
TTauri: 350
beStar: 182
nan: 0
wN: 5


""";

# %%
df1['evolstage_flame'] = df1['evolstage_flame'].fillna(0)

conditions = [
    ((df1['evolstage_flame'].astype(int) >= 100) &  (df1['evolstage_flame'].astype(int) < 300)),
    ((df1['evolstage_flame'].astype(int) >= 300) &  (df1['evolstage_flame'].astype(int) < 360)),
    ((df1['evolstage_flame'].astype(int) >= 360) &  (df1['evolstage_flame'].astype(int) < 420)),
    ((df1['evolstage_flame'].astype(int) >= 420) &  (df1['evolstage_flame'].astype(int) < 490)),
    ((df1['evolstage_flame'].astype(int) >= 490) &  (df1['evolstage_flame'].astype(int) < 860)),
    ((df1['evolstage_flame'].astype(int) >= 860) &  (df1['evolstage_flame'].astype(int) < 890)),
    ((df1['evolstage_flame'].astype(int) >= 890) &  (df1['evolstage_flame'].astype(int) < 1290)),
    (df1['evolstage_flame'].astype(int) >= 1290),
    (df1['evolstage_flame'].astype(int) == 0),
]

values = ['(100-300) zero age main sequence                  ', 
          '(300-360) first minimum of Teff for massive stars ', 
          '(360-420) main sequence turn-off                  ', 
          '(420-490) central hydrogen mass fraction = 0.0    ', 
          '(490-860) base of the red giant brach (RGB)       ',
          '(860-890) maximun L along the RGB bump            ',
          '(890-1290) minimum L along the RGB bump           ',
          '(1290-1390) tip the RGB                           ',
          'NA                                                ']

df1['evolstage_type'] = np.select(conditions, values)

# %%
unique_evolstage_type = sp.unique(df1['evolstage_type'].astype(str))

for i in unique_evolstage_type:
    print(str(i) + ": " + str(df1[df1['evolstage_type'] == i].shape[0]))
# Out:
# (100-300) zero age main sequence                  : 1009863
# (1290-1390) tip the RGB                           : 142
# (300-360) first minimum of Teff for massive stars : 710023
# (360-420) main sequence turn-off                  : 518220
# (420-490) central hydrogen mass fraction = 0.0    : 261880
# (490-860) base of the red giant brach (RGB)       : 197497
# (860-890) maximun L along the RGB bump            : 1669
# (890-1290) minimum L along the RGB bump           : 3708
# NA                                                : 1312165

# %%
"""

(100-300) zero age main sequence                  : 1009863
(1290-1390) tip the RGB                           : 142
(300-360) first minimum of Teff for massive stars : 710023
(360-420) main sequence turn-off                  : 518220
(420-490) central hydrogen mass fraction = 0.0    : 261880
(490-860) base of the red giant brach (RGB)       : 197497
(860-890) maximun L along the RGB bump            : 1669
(890-1290) minimum L along the RGB bump           : 3708
NA                                                : 1312165

""";

# %%
df_all.shape[0]
# Out:
# 3576194

# %% [markdown]
# ## Filters

# %%
r2_xp_rvs = df_all[(df_all['has_xp_sampled'] == True) & (df_all['has_rvs'] == True)]
r2_xp_rvs.shape[0]
# Out:
# 23405

# %%
r2_xp_not_rvs = df_all[(df_all['has_xp_sampled'] == True) & (df_all['has_rvs'] == False)]
r2_xp_not_rvs.shape[0]
# Out:
# 655888

# %%
r2_rvs_not_xp = df_all[(df_all['has_xp_sampled'] == False) & (df_all['has_rvs'] == True)]
r2_rvs_not_xp.shape[0]
# Out:
# 1511

# %%
r2_xp_sampled = df_all[(df_all['has_xp_sampled'] == True)]
r2_xp_sampled.shape[0]
# Out:
# 679293

# %%
r2_rvs = df_all[(df_all['has_rvs'] == True)]
r2_rvs.shape[0]
# Out:
# 24916

# %%
r2_xp_continuous = df_all[(df_all['has_xp_continuous'] == True)]
r2_xp_continuous.shape[0]
# Out:
# 3109183

# %%
r2_epoch_photometry = df_all[(df_all['has_epoch_photometry'] == True)]
r2_epoch_photometry.shape[0]
# Out:
# 78833

# %%
r2_mcmc_gspphot = df_all[(df_all['has_mcmc_gspphot'] == True)]
r2_mcmc_gspphot.shape[0]
# Out:
# 2983041

# %%
r2_mcmc_msc = df_all[(df_all['has_mcmc_msc'] == True)]
r2_mcmc_msc.shape[0]
# Out:
# 3444499

# %% [markdown]
# ## Change filter to desired target

# %%
#df1 = r2_xp_rvs
#df1 = r2_xp_not_rvs
#df1 = r2_rvs_not_xp
#df1 = r2_xp_rvs
#df1 = r2_xp_sampled
#df1 = r2_rvs
#df1 = r2_xp_continuous
#df1 = r2_epoch_photometry
#df1 = r2_mcmc_gspphot
#df1 = r2_mcmc_msc

#df1 = df_all

# %%
df1.shape[0]
# Out:
# 4015167

# %%
df_zero_age_main_sequence = df1[df1['evolstage_type'] == "(100-300) zero age main sequence                  "]
df_tip_the_RGB = df1[df1['evolstage_type'] == "(1290-1390) tip the RGB                           "]
df_first_minimum_of_Teff_for_massive_stars = df1[df1['evolstage_type'] == "(300-360) first minimum of Teff for massive stars "]
df_main_sequence_turn_off = df1[df1['evolstage_type'] == "(360-420) main sequence turn-off                  "]
df_central_hydrogen_mass_fraction = df1[df1['evolstage_type'] == "(420-490) central hydrogen mass fraction = 0.0    "]
df_base_of_the_RGB = df1[df1['evolstage_type'] == "(490-860) base of the red giant brach (RGB)       "]
df_maximun_L_along_the_RGB_bump = df1[df1['evolstage_type'] == "(860-890) maximun L along the RGB bump            "]
df_minimun_L_along_the_RGB_bump = df1[df1['evolstage_type'] == "(890-1290) minimum L along the RGB bump           "]

print("zero_age_main_sequence: " + str(df_zero_age_main_sequence.shape[0]))
print("tip_the_RGB: " + str(df_tip_the_RGB.shape[0]))
print("first_minimum_of_Teff_for_massive_stars: " + str(df_first_minimum_of_Teff_for_massive_stars.shape[0]))
print("main_sequence_turn_off: " + str(df_main_sequence_turn_off.shape[0]))
print("central_hydrogen_mass_fraction: " + str(df_central_hydrogen_mass_fraction.shape[0]))
print("base_of_the_RGB: " + str(df_base_of_the_RGB.shape[0]))
print("maximun_L_along_the_RGB_bump: " + str(df_maximun_L_along_the_RGB_bump.shape[0]))
print("minimun_L_along_the_RGB_bump: " + str(df_minimun_L_along_the_RGB_bump.shape[0]))
# Out:
# zero_age_main_sequence: 1009863
# tip_the_RGB: 142
# first_minimum_of_Teff_for_massive_stars: 710023
# main_sequence_turn_off: 518220
# central_hydrogen_mass_fraction: 261880
# base_of_the_RGB: 197497
# maximun_L_along_the_RGB_bump: 1669
# minimun_L_along_the_RGB_bump: 3708

# %%
unique_classlabel = sp.unique(df1['classlabel_espels'].astype(str))

for i in unique_classlabel:
    print(str(i) + ": " + str(df1[df1['classlabel_espels'] == i].shape[0]))
# Out:
# HerbigStar: 90
# PlanetaryNebula: 2
# RedDwarfEmStar: 28
# TTauri: 350
# beStar: 182
# nan: 0
# wN: 5

# %%
df_HerbigStar = df1[df1['classlabel_espels'] == "HerbigStar"]
df_PlanetaryNebula = df1[df1['classlabel_espels'] == "PlanetaryNebula"]
df_RedDwarfEmStar = df1[df1['classlabel_espels'] == "RedDwarfEmStar"]
df_TTauri = df1[df1['classlabel_espels'] == "TTauri"]
df_beStar = df1[df1['classlabel_espels'] == "beStar"]
df_wN = df1[df1['classlabel_espels'] == "wN"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.style.library['seaborn']

df = df_HerbigStar
if df.shape[0] > 1:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" HerbigStar Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_TTauri
if df.shape[0] > 1:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="orange", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" TTauri Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_beStar
if df.shape[0] > 1:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="b", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" beStar Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_RedDwarfEmStar
if df.shape[0] > 1:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" RedDwarf Em Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

plt.show()

# %%
idx = 50000

# %%
df_Alpha = df1[df1['alphafe_gspspec'].notna()][0:idx]
df_Alpha.sort_values(['alphafe_gspspec'], ascending=[False], inplace=True)

df_Fe = df1[df1['fem_gspspec'].notna()][0:idx]
df_Fe.sort_values(['fem_gspspec'], ascending=[False], inplace=True)

df_Si = df1[df1['sife_gspspec'].notna()][0:idx]
df_Si.sort_values(['sife_gspspec'], ascending=[False], inplace=True)

df_Ca = df1[df1['cafe_gspspec'].notna()][0:idx]
df_Ca.sort_values(['cafe_gspspec'], ascending=[False], inplace=True)

df_Ti = df1[df1['tife_gspspec'].notna()][0:idx]
df_Ti.sort_values(['tife_gspspec'], ascending=[False], inplace=True)

df_Mg = df1[df1['mgfe_gspspec'].notna()][0:idx]
df_Mg.sort_values(['mgfe_gspspec'], ascending=[False], inplace=True)

df_Nd = df1[df1['ndfe_gspspec'].notna()][0:idx]
df_Nd.sort_values(['ndfe_gspspec'], ascending=[False], inplace=True)

df_FeII = df1[df1['feiim_gspspec'].notna()][0:idx]
df_FeII.sort_values(['feiim_gspspec'], ascending=[False], inplace=True)

df_S = df1[df1['sfe_gspspec'].notna()][0:idx]
df_S.sort_values(['sfe_gspspec'], ascending=[False], inplace=True)

df_Zr = df1[df1['zrfe_gspspec'].notna()][0:idx]
df_Zr.sort_values(['zrfe_gspspec'], ascending=[False], inplace=True)

df_N = df1[df1['nfe_gspspec'].notna()][0:idx]
df_N.sort_values(['nfe_gspspec'], ascending=[False], inplace=True)

df_Cr = df1[df1['crfe_gspspec'].notna()][0:idx]
df_Cr.sort_values(['crfe_gspspec'], ascending=[False], inplace=True)

df_Ce = df1[df1['cefe_gspspec'].notna()][0:idx]
df_Ce.sort_values(['cefe_gspspec'], ascending=[False], inplace=True)

df_Ni = df1[df1['nife_gspspec'].notna()][0:idx]
df_Ni.sort_values(['nife_gspspec'], ascending=[False], inplace=True)

print("Alpha/Fe: " + str(df_Alpha.shape[0]))
print("Fe/M: " + str(df_Fe.shape[0]))
print("Si/Fe: " + str(df_Si.shape[0]))
print("Ca/Fe: " + str(df_Ca.shape[0]))
print("Ti/Fe: " + str(df_Ti.shape[0]))
print("Mg/Fe: " + str(df_Mg.shape[0]))
print("Nd/Fe: " + str(df_Nd.shape[0]))
print("FeII/M: " + str(df_FeII.shape[0]))
print("S/Fe: " + str(df_S.shape[0]))
print("Zr/Fe: " + str(df_Zr.shape[0]))
print("N/Fe:  " + str(df_N.shape[0]))
print("Cr/Fe: " + str(df_Cr.shape[0]))
print("Ce/Fe: " + str(df_Ce.shape[0]))
print("Ni/Fe: " + str(df_Ni.shape[0]))
# Out:
# Alpha/Fe: 50000
# Fe/M: 50000
# Si/Fe: 21877
# Ca/Fe: 50000
# Ti/Fe: 22325
# Mg/Fe: 16019
# Nd/Fe: 1287
# FeII/M: 2106
# S/Fe: 6016
# Zr/Fe: 279
# N/Fe:  13941
# Cr/Fe: 5862
# Ce/Fe: 2499
# Ni/Fe: 11406

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.style.library['seaborn']

df = df_Alpha
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Alpha/Fe Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_Fe
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="orange", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Fe/M Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_Si
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="b", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Si/Fe Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_Ca
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Ca/Fe Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

plt.show()

# %%
df_main_sequence = df1[df1['Star_Type'] == "main_sequence"][0:idx]
df_red_clump = df1[df1['Star_Type'] == "red_clump"][0:idx]
df_red_giants = df1[df1['Star_Type'] == "red_giants"][0:idx]
df_subgiants = df1[df1['Star_Type'] == "subgiants"][0:idx]
df_turnoff = df1[df1['Star_Type'] == "turnoff"][0:idx]

print("main_sequence: " + str(df_main_sequence.shape[0]))
print("red_clump: " + str(df_red_clump.shape[0]))
print("red_giants: " + str(df_red_giants.shape[0]))
print("subgiants: " + str(df_subgiants.shape[0]))
print("turnoff: " + str(df_turnoff.shape[0]))
# Out:
# main_sequence: 50000
# red_clump: 14235
# red_giants: 50000
# subgiants: 50000
# turnoff: 50000

# %%
#plt.style.use('dark_background')

# reset rcParams
#plt.rcParams.update(Ipython_default)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.style.library['seaborn']

df = df_main_sequence
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="b", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Main Sequence Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_red_clump
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="orange", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Red Clump Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_red_giants
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Red Giant Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_subgiants
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="g", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Subgiant Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

df = df_turnoff
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="b", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Turnoff Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)

"""sns.jointplot(
    data=df_samp, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True);
sns.jointplot(
    data=df_samp, x="l", y="b",  color="r", height=6, kind="kde", fill=True, dropna=True);
sns.jointplot(
    data=df_samp, x="l", y="b",  color="r", height=6, kind="reg", dropna=True)""";

plt.show()

# %%
start_ids = 0
end_idx = start_ids + 50000

s = 'b'
#s = 'l'

df = df1[df1['spectraltype_esphs'] == "O"].sort_values(s)
df_O = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "B"].sort_values(s)
df_B = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "A"].sort_values(s)
df_A = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "F"].sort_values(s)
df_F = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "G"].sort_values(s)
df_G = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "K"].sort_values(s)
df_K = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "M"].sort_values(s)
df_M = df[start_ids:end_idx]

df = df1[df1['spectraltype_esphs'] == "CSTAR"].sort_values(s)
df_CSTAR = df[start_ids:end_idx]

print("Class O: " + str(df_O.shape[0]))
print("Class B: " + str(df_B.shape[0]))
print("Class A: " + str(df_A.shape[0]))
print("Class F: " + str(df_F.shape[0]))
print("Class G: " + str(df_G.shape[0]))
print("Class K: " + str(df_K.shape[0]))
print("Class M: " + str(df_M.shape[0]))
print("Class CSTAR: " + str(df_CSTAR.shape[0]))
# Out:
# Class O: 12400
# Class B: 50000
# Class A: 50000
# Class F: 50000
# Class G: 50000
# Class K: 50000
# Class M: 50000
# Class CSTAR: 1095

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.style.library['seaborn']

df = df_CSTAR
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="orange", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Carbon Stars [CSTAR]: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_O
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="b", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class O Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_B
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="b", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class B Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_A
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="violet", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class A Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_F
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="orange", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class F Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_G
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="y", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class G Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_K
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class K Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

df = df_M
if df.shape[0] > 0:
    p = sns.jointplot(
        data=df, x="l", y="b",  color="r", height=6, kind="scatter", dropna=True)
    p.fig.suptitle(" Class M Stars: " + str(df.shape[0]))
    p.fig.tight_layout()
    p.fig.subplots_adjust(top=0.95)
    plt.show()

print("\nDone!")
# Out:
# Done!

# %%
unique_classlabel = sp.unique(df1['classlabel_espels'].astype(str))
for i in unique_classlabel:
    print(str(i) + ": " + str(df1[df1['classlabel_espels'] == i].shape[0]))

print("\nmain_sequence: " + str(df_main_sequence.shape[0]))
print("red_clump: " + str(df_red_clump.shape[0]))
print("red_giants: " + str(df_red_giants.shape[0]))
print("subgiants: " + str(df_subgiants.shape[0]))
print("turnoff: " + str(df_turnoff.shape[0]))

print("\nClass O: " + str(df_O.shape[0]))
print("Class B: " + str(df_B.shape[0]))
print("Class A: " + str(df_A.shape[0]))
print("Class F: " + str(df_F.shape[0]))
print("Class G: " + str(df_G.shape[0]))
print("Class K: " + str(df_K.shape[0]))
print("Class M: " + str(df_M.shape[0]))
print("Class CSTAR: " + str(df_CSTAR.shape[0]))

print("\nzero_age_main_sequence: " + str(df_zero_age_main_sequence.shape[0]))
print("tip_the_RGB: " + str(df_tip_the_RGB.shape[0]))
print("first_minimum_of_Teff_for_massive_stars: " + str(df_first_minimum_of_Teff_for_massive_stars.shape[0]))
print("main_sequence_turn_off: " + str(df_main_sequence_turn_off.shape[0]))
print("central_hydrogen_mass_fraction: " + str(df_central_hydrogen_mass_fraction.shape[0]))
print("base_of_the_RGB: " + str(df_base_of_the_RGB.shape[0]))
print("maximun_L_along_the_RGB_bump: " + str(df_maximun_L_along_the_RGB_bump.shape[0]))
print("minimun_L_along_the_RGB_bump: " + str(df_minimun_L_along_the_RGB_bump.shape[0]))

print("\nAlpha/Fe: " + str(df_Alpha.shape[0]))
print("Fe/M: " + str(df_Fe.shape[0]))
print("Si/Fe: " + str(df_Si.shape[0]))
print("Ca/Fe: " + str(df_Ca.shape[0]))
print("Ti/Fe: " + str(df_Ti.shape[0]))
print("Mg/Fe: " + str(df_Mg.shape[0]))
print("Nd/Fe: " + str(df_Nd.shape[0]))
print("FeII/M: " + str(df_FeII.shape[0]))
print("S/Fe: " + str(df_S.shape[0]))
print("Zr/Fe: " + str(df_Zr.shape[0]))
print("N/Fe:  " + str(df_N.shape[0]))
print("Cr/Fe: " + str(df_Cr.shape[0]))
print("Ce/Fe: " + str(df_Ce.shape[0]))
print("Ni/Fe: " + str(df_Ni.shape[0]))
# Out:
# HerbigStar: 90
# PlanetaryNebula: 2
# RedDwarfEmStar: 28
# TTauri: 350
# beStar: 182
# nan: 0
# wN: 5
#
# main_sequence: 50000
# red_clump: 14235
# red_giants: 50000
# subgiants: 50000
# turnoff: 50000
#
# Class O: 12400
# Class B: 50000
# Class A: 50000
# Class F: 50000
# Class G: 50000
# Class K: 50000
# Class M: 50000
# Class CSTAR: 1095
#
# zero_age_main_sequence: 1009863
# tip_the_RGB: 142
# first_minimum_of_Teff_for_massive_stars: 710023
# main_sequence_turn_off: 518220
# central_hydrogen_mass_fraction: 261880
# base_of_the_RGB: 197497
# maximun_L_along_the_RGB_bump: 1669
# minimun_L_along_the_RGB_bump: 3708
#
# Alpha/Fe: 50000
# Fe/M: 50000
# Si/Fe: 21877
# Ca/Fe: 50000
# Ti/Fe: 22325
# Mg/Fe: 16019
# Nd/Fe: 1287
# FeII/M: 2106
# S/Fe: 6016
# Zr/Fe: 279
# N/Fe:  13941
# Cr/Fe: 5862
# Ce/Fe: 2499
# Ni/Fe: 11406

# %% [markdown]
# ### Select target and range to plot XP/RVS spectra

# %%
#target = df_zero_age_main_sequence[0:5]
target = df_tip_the_RGB[0:5]
#target = df_first_minimum_of_Teff_for_massive_stars[0:5]
#target = ddf_main_sequence_turn_off[0:5]
#target = df_central_hydrogen_mass_fraction[0:5]
#target = df_base_of_the_RGB[0:5]
#target = df_maximun_L_along_the_RGB_bump[0:5]
#target = df_minimun_L_along_the_RGB_bump[0:5]

#target = df_Alpha[0:5]
#target = df_Fe[0:5]
#target = df_Si[0:5]
#target = df_Ca[0:5]
#target = df_Ti[0:5]
#target = df_Mg[0:5]
#target = df_Nd[0:5]
#target = df_FeII[0:5]
#target = df_S[0:5]
#target = df_Zr[0:5]
#target = df_N[0:5]
#target = df_Cr[0:5]
#target = df_Ce[0:5]
#target = df_Ni[0:5]

#target = df_HerbigStar[0:5]
#target = df_RedDwarfEmStar[0:5]
#target = df_TTauri[0:5]
#target = df_beStar[0:5]
#target = df_wN[0:5]

#target = df_main_sequence[0:5]
#target = df_red_clump[0:5]
#target = df_red_giants[0:5]
#target = df_subgiants[0:5]
#target = df_turnoff[0:5]

#target = df_O[0:5]
#target = df_B[0:5]
#target = df_A[0:5]
#target = df_F[0:5]
#target = df_G[0:5]
#target = df_K[0:5]
#target = df_M[0:5]

#target = df_CSTAR[0:5]

results = target['source_id'].values.tolist()

# %%
results
# Out:
# [41624520930373248,
#  47815291087406592,
#  53587035642731776,
#  85542489972956672,
#  86180168061883520]

# %%
def make_labels(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

# %%
def make_RVS_canvas(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    yMin = float(xp['flux'].min())
    #yRangeMin = yMin + 0.2
    yRangeMin = 1.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('Ca II 8498', xy=[8498, yRangeMin ],  rotation=-90, color='red')
    plt.annotate('Ca II 8542', xy=[8542, yRangeMin ], rotation=-90, color='red')
    plt.annotate('Pa14 8600', xy=[8600, yRangeMin - 0.3 ], rotation=-90, color='red')
    plt.annotate('Ca II 8662.1', xy=[8662, yRangeMin ],  rotation=-90, color='red')

# %%
# Plotter ==============================================
def make_canvas(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    plt.xticks([3839, 3889, 3970, 4101, 4340, 4472, 4861, 5175, 5270, 5411, 5755, 5895, 6302,
               6365, 6562, 6562, 6890, 7135, 7500, 7775, 8000, 8498, 8542, 8662, 9000, 9200])
    
    xLabels = (3839, 3889, 3970, 4101, 4340, 4472, 4861, 5175, 5270, 5411, 5755, 5895, 6302,
               6365, 6562, 6562, 6890, 7135, 7500, 7775, 8000, 8498, 8542, 8662, 9000, 9200)

    plt.xticks(xLabels, rotation=90)

    yMin = float(xp['flux'].min())
    #yRangeMin = yMin + 0.2
    yRangeMin = 0.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('CN 3839', xy=[3839,   yRangeMin + 0.6],  rotation=-90)
    plt.annotate('H-zeta 3889', xy=[3889, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-epsilon 3970', xy=[3970, yRangeMin +  0.6],  rotation=-90, color='red')
    plt.annotate('H-delta 4101', xy=[4101, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-gamma 4340', xy=[4340, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('He I 4471.7', xy=[4472, yRangeMin + .20],  rotation=-90, color='orange')
    plt.annotate('H-beta 4861', xy=[4861, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('Mg I 5175', xy=[5175, yRangeMin + .20],  rotation=-90)
    plt.annotate('Fe I 5270', xy=[5270, yRangeMin +  .20],  rotation=-90)
    plt.annotate('He II 5411', xy=[5411, yRangeMin +  .20],  rotation=-90, color='orange')
    plt.annotate('N II 5755', xy=[5755, yRangeMin +  .20],  rotation=-90)
    plt.annotate('D1 Na I 5895', xy=[5895, yRangeMin +  .20],  rotation=-90, color='blue')
    plt.annotate('OI 6302', xy=[6302, yRangeMin +  .20],  rotation=-90, color='green')
    plt.annotate('OI 6365.5', xy=[6365, yRangeMin +  .20],  rotation=-90, color='green')
    plt.annotate('H-alpha 6562', xy=[6562, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('CN 6890', xy=[6890, yRangeMin +  .20],  rotation=-90)
    plt.annotate('Ar III 7135', xy=[7135, yRangeMin +  .20],  rotation=-90)
    plt.annotate('O I 7775', xy=[7775, yRangeMin +  .20], rotation=-90, color='green')
    plt.annotate('Ca II 8498', xy=[8498, yRangeMin +  .35],  rotation=-90, color='blue')
    plt.annotate('Ca II 8542', xy=[8542, yRangeMin +  .30], rotation=-90, color='blue')
    plt.annotate('Ca II 8662.1', xy=[8662, yRangeMin +  .30],  rotation=-90, color='blue')


def Hydrogen_lines(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    plt.xticks([3835, 3889, 3970, 4101, 4340, 4861, 6000, 6562, 7000, 8000, 9000, 10000])
    
    xLabels = (3835, 3889, 3970, 4101, 4340, 4861, 6000, 6562, 7000, 8000, 9000, 10000)

    plt.xticks(xLabels, rotation=90)

    yMin = float(xp['flux'].min())
    #yRangeMin = yMin + 0.2
    yRangeMin = 0.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('H12 3750', xy=[3750, yRangeMin +  .50],  rotation=-90, color='red')
    plt.annotate('H11 3771', xy=[3771, yRangeMin -  .35],  rotation=-90, color='red')
    plt.annotate('H10 3798', xy=[3798, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H9 3835', xy=[3835, yRangeMin -  .10],  rotation=-90, color='red')

    plt.annotate('H8-zeta 3889', xy=[3889, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-epsilon 3970', xy=[3970, yRangeMin +  0.6],  rotation=-90, color='red')
    plt.annotate('H-delta 4101', xy=[4101, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-gamma 4340', xy=[4340, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('H-beta 4861', xy=[4861, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('H-alpha 6562', xy=[6562, yRangeMin +  .20],  rotation=-90, color='red')

# %%
make_canvas_flag = "Y"

hydrogen_lines_flag = "N"

# %%
#Ipython_default = plt.rcParams.copy()

# reset rcParams
#plt.rcParams.update(Ipython_default)

#plt.style.use('dark_background')

#print("Backup default plot background. \nSet Dark background.")

# reset rcParams

plt.rcParams.update(Ipython_default)

#plt.style.use('dark_background')

# %%
from astroquery.gaia import Gaia
from astroquery.simbad import Simbad 

import astropy.coordinates as coord
import astropy.units as u

import pyvo as vo

import matplotlib.pyplot as plt


for idx in range(0, len(results)):
    #print("1: " + str(results[idx]) + ' has_xp_sampled: ' + str(target['has_xp_sampled'].iloc[idx]))                        # 1st print statement
    if target['has_xp_sampled'].iloc[idx] == True:
        datalink = Gaia.load_data(results[idx], data_structure = 'INDIVIDUAL', retrieval_type = 'XP_SAMPLED')
        outputs = [datalink[key][0] for key in datalink.keys()]

        #print("2: " + str(results[idx]) + " Number of stars with XP Spectra: " + str(len(outputs)))                         # 2nd print statement
        if outputs is not None:
            #print("3: " + "outputs is not None")                                                                            # 3rd print statement
            if len(outputs) > 0:
                #print("4: " + "len(outputs): " + str(len(outputs)))                                                         # 4th print statement

                # ====================================================================================
                xRa = str(target['ra'].iloc[idx])
                yDec = str(target['dec'].iloc[idx])

                print("Ra: " + str(xRa))                                                                            
                print("Dec: " + str(yDec))                                                                         

                result_table = Simbad.query_region(coord.SkyCoord(str(xRa) + " " + str(yDec), 
                    unit=(u.deg, u.deg),frame='icrs'))

                #print("5: " + str(result_table))                                                                            # 5th print statement
                if result_table is not None:
                    if len(result_table) > 0:
                        #print("6: " + "Ra: " + str(xRa))                                                                     # 6th print statement
                        #print("7: " + "Dec: " + str(yDec))                                                                   # 7th print statement

                        target1 = result_table['MAIN_ID'][0]
                        print(target1)

                        object = Simbad.query_object(target1)

                        tap_service = vo.dal.TAPService("http://simbad.u-strasbg.fr/simbad/sim-tap")

                        tap_sql = "SELECT main_id, sp_type, otype_txt, otype_longname \
                                        FROM basic JOIN ident ON oidref = oid \
                                            JOIN otypedef ON basic.otype = otypedef.otype \
                                        WHERE id = '" + str(target1) + "';"

                        tap_results = tap_service.search(tap_sql)
                        sptype = tap_results['sp_type']
                        txt = str(sptype).split("=")
                        txt = str(txt).replace("['", "")
                        sp_txt = str(txt).replace("']", "")
                        print("Simbad star subclass: " + str(sp_txt))


                print("BP_RP star subclass: " + str(target['SpT2'].iloc[idx]))
                #print("BP_RP dereddened star subclass: " + str(target['SpT2_dereddened'].iloc[idx]))
                print("classlabel_espels: " + str(target['classlabel_espels'].iloc[idx]))
                print("Star Type: " + str(target['Star_Type'].iloc[idx]))

                # ====================================================================================


                xp      = outputs[0].to_table()                      

                # Add flux-density columns ============================
                xp['flux_jy']         = xp['flux'].to(u.Jansky, equivalencies = u.spectral_density(xp['wavelength'].value * xp['wavelength'].unit))
                xp['flux_mjy']        = xp['flux_jy'].to(u.millijansky)
                xp['flux_mjy'].format = '7.4f'
                
                # =========
                
                #display(xp)

                # =========

                fig       = plt.figure(figsize=[20,10])

                yRangeMax = float(xp['flux'].max())

                plt.plot(xp['wavelength']*10, xp['flux']/yRangeMax * 2, linewidth = 2) 
                plt.title('XP_SAMPLED Spectra Gaia DR3 Class '+ str(target['spectraltype_esphs'].iloc[idx]) + 
                ' \nLogG: ' + str(round(target['logg_gspphot'].iloc[idx], 2)) + 
                '    Teff: ' + str(round(target['teff_gspphot'].iloc[idx],0)) +
                '    Mass: ' + str(round(target['mass_flame'].iloc[idx],2)) +
                '    Luminosity: ' + str(round(target['lum_flame'].iloc[idx],2)) +
                '    Radius: ' + str(round(target['radius_gspphot'].iloc[idx],2)) +
                '    Age: ' + str(round(target['age_flame'].iloc[idx],2)) +
                '    [M/H]: ' + str(round(target['mh_gspphot'].iloc[idx],2)) +
                '    [Alpha/Fe]: ' + str(round(target['alphafe_gspspec'].iloc[idx],2)) +
                '\nRa: ' + str(target['ra'].iloc[idx]) + "    Dec: " + str(target['dec'].iloc[idx]) +
                ' \nSolution_ID: ' + str(target['source_id'].iloc[idx]), fontsize=15)

                if make_canvas_flag == "Y":
                    make_canvas(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", fontsize = 12)
                #else:
                    #make_labels()

                if hydrogen_lines_flag == "Y":
                    Hydrogen_lines(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", fontsize = 12)

                plt.show()


        #print(str(results[idx]) + ' has_rvs: ' + str(target['has_rvs'].iloc[idx]))
        if target['has_rvs'].iloc[idx] == True:
            datalinkRVS = Gaia.load_data(results[idx], data_structure = 'INDIVIDUAL', retrieval_type = 'RVS')
            outputsRVS = [datalinkRVS[key][0] for key in datalinkRVS.keys()]
            #print("datalinkRVS: " + str(datalinkRVS))

            if outputsRVS is not None:
                if len(outputsRVS) >0:
                    xpRVS      = outputsRVS[0].to_table()

                    # =========
                
                    #display(xpRVS)

                    # =========

                    fig       = plt.figure(figsize=[20,10])

                    yRangeMax = float(xpRVS['flux'].max())

                    plt.plot(xpRVS['wavelength']*10, xpRVS['flux']/yRangeMax * 2, linewidth = 2) 
                    plt.title('RVS Spectra Gaia DR3 Class '+ str(target['spectraltype_esphs'].iloc[idx]) + 
                    ' \nLogG: ' + str(round(target['logg_gspphot'].iloc[idx], 2)) + 
                    '    Teff: ' + str(round(target['teff_gspphot'].iloc[idx],0)) +
                    '    Mass: ' + str(round(target['mass_flame'].iloc[idx],2)) +
                    '    Luminosity: ' + str(round(target['lum_flame'].iloc[idx],2)) +
                    '    Radius: ' + str(round(target['radius_gspphot'].iloc[idx],2)) +
                    '    Age: ' + str(round(target['age_flame'].iloc[idx],2)) +
                    '    [M/H]: ' + str(round(target['mh_gspphot'].iloc[idx],2)) +
                    '    [Alpha/Fe]: ' + str(round(target['alphafe_gspspec'].iloc[idx],2)) +
                    '\nRa: ' + str(target['ra'].iloc[idx]) + "    Dec: " + str(target['dec'].iloc[idx]) +
                    ' \nSolution_ID: ' + str(target['source_id'].iloc[idx]), fontsize=15)

                    if make_canvas_flag == "Y":
                        #make_canvas(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", fontsize = 12)
                        #make_labels()
                        make_RVS_canvas()
                        
                    plt.show()


        #print(str(results[idx]) + ' has_xp_continuous: ' + str(target['has_xp_continuouss'].iloc[idx]))
        if target['has_xp_continuous'].iloc[idx] == True:
            datalinkXPC = Gaia.load_data(results[idx], data_structure = 'INDIVIDUAL', retrieval_type = 'XP_CONTINUOUS')
            outputsXPC = [datalinkXPC[key][0] for key in datalinkXPC.keys()]
            #print("datalinkXPC: " + str(datalinkXPC))

           

print("\nDone!")
# Out:
# Ra: 61.850962358756654
# Dec: 22.73786774382882
# Cl* Melotte   22   PELS     100
# Simbad star subclass: [""]
# BP_RP star subclass: M2.5V
# classlabel_espels: nan
# Star Type: red_giants
# Ra: 42.34735159801342
# Dec: 21.603146189009077
# BP_RP star subclass: M3V
# classlabel_espels: nan
# Star Type: red_giants
# Ra: 38.41576397625128
# Dec: 18.81599338527956
# TYC 1219-8-1
# Simbad star subclass: [""]
# BP_RP star subclass: M3.5V
# classlabel_espels: nan
# Star Type: red_giants
# Done!

# %%
"""
expected: 'ALL' or any of ['EPOCH_PHOTOMETRY', 'XP_CONTINUOUS', 'XP_SAMPLED', 'RVS', 'MCMC_GSPPHOT', 'MCMC_MSC']
""";

# %%
df0 = pd.concat([df_HerbigStar, df_RedDwarfEmStar, df_TTauri, df_beStar, df_wN], ignore_index=True, sort=False)
df0.shape[0]

# %%
def plotly_classlabel(r1, x1, target1, title1):
    fig2 = px.scatter(r1, x='ra', y='dec', hover_data=[x1,'source_id','ra','dec','teff_gspphot','logg_gspphot','mh_gspphot',
                     'distance_gspphot','radius_gspphot','spectraltype_esphs', 'classlabel_espels','Star_Type',
                     'lum_flame','mass_flame', 'age_flame', 'evolstage_flame', 'bp_rp', 'ebpminrp_gspphot'], 
    color=x1, color_continuous_scale='jet',opacity=0.5,
    title=str(target1)+": " + str(title1))
    #fig2['layout']['xaxis']['autorange']= "reversed"
    #fig2['layout']['yaxis']['autorange']= "reversed"
    fig2.update_traces(marker={'size': 7})
    fig2.show()

# %%
target1 = ""

plotly_classlabel(df0, 'classlabel_espels', target1, "Color = classlabel_espels")

# %%
target1 = ""

plotly_classlabel(df0, 'evolstage_type', target1, "Color = evolstage_type")

# %%
# reset rcParams
#plt.rcParams.update(Ipython_default)

fig = plt.figure(figsize=(10, 8))

plt.subplot(111)
image1 = plt.scatter(df_HerbigStar['ra'], df_HerbigStar['dec'], label="HerbigStar " + str(df_HerbigStar.shape[0]), marker='o', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")
image2 = plt.scatter(df_RedDwarfEmStar['ra'], df_RedDwarfEmStar['dec'], label="RedDwarfEmStar " + str(df_RedDwarfEmStar.shape[0]), marker='o', linewidth=0,
            c='red',edgecolor='k',cmap="jet_r")
image3 = plt.scatter(df_TTauri['ra'], df_TTauri['dec'], label="TTauri " + str(df_TTauri.shape[0]), marker='o', linewidth=0,
            c='orange',edgecolor='k',cmap="jet_r")
image4 = plt.scatter(df_beStar['ra'], df_beStar['dec'], label="beStar " + str(df_beStar.shape[0]), marker='o', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
ax = plt.gca()
#plt.gca().invert_yaxis()
plt.xlabel('Ra', fontsize=15)
plt.ylabel('Dec', fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.title('Gaia DR3', fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
print(df1.shape[0])

print("\n< Not Null >\n")

print("Alpha/Fe: " +str(df1[df1['alphafe_gspspec'].notna()].shape[0]))
print("Fe/M: " +str(df1[df1['fem_gspspec'].notna()].shape[0]))
print("Si/Fe: " +str(df1[df1['sife_gspspec'].notna()].shape[0]))
print("Ca/Fe: " +str(df1[df1['cafe_gspspec'].notna()].shape[0]))
print("Ti/Fe: " +str(df1[df1['tife_gspspec'].notna()].shape[0]))
print("Mg/Fe: " +str(df1[df1['mgfe_gspspec'].notna()].shape[0]))
print("Nd/Fe: " +str(df1[df1['ndfe_gspspec'].notna()].shape[0]))
print("FeII/M: " +str(df1[df1['feiim_gspspec'].notna()].shape[0]))
print("S/Fe: " +str(df1[df1['sfe_gspspec'].notna()].shape[0]))
print("Zr/Fe: " +str(df1[df1['zrfe_gspspec'].notna()].shape[0]))
print("N/Fe:  " +str(df1[df1['nfe_gspspec'].notna()].shape[0]))
print("Cr/Fe: " +str(df1[df1['crfe_gspspec'].notna()].shape[0]))
print("Ce/Fe: " +str(df1[df1['cefe_gspspec'].notna()].shape[0]))
print("Ni/Fe: " +str(df1[df1['nife_gspspec'].notna()].shape[0]))

# %%
unique_spectraltype = sp.unique(df1['spectraltype_esphs'].astype(str))

for i in unique_spectraltype:
    print(str(i) + ": " + str(df1[df1['spectraltype_esphs'] == i].shape[0]))

# %% [markdown]
# ## Change idx to fit plots

# %%
idx = 1000

# %%
df_alpha_fe = df1[df1['alphafe_gspspec'].notna()][0:idx]
df_fe_m = df1[df1['fem_gspspec'].notna()][0:idx]
df_si_fe = df1[df1['sife_gspspec'].notna()][0:idx]
df_ca_fe = df1[df1['cafe_gspspec'].notna()][0:idx]
df_ti_fe = df1[df1['tife_gspspec'].notna()][0:idx]
df_mg_fe = df1[df1['mgfe_gspspec'].notna()][0:idx]
df_nd_fe = df1[df1['ndfe_gspspec'].notna()][0:idx]
df_feii_m = df1[df1['feiim_gspspec'].notna()][0:idx]
df_s_fe  = df1[df1['sfe_gspspec'].notna()][0:idx]
df_zr_fe = df1[df1['zrfe_gspspec'].notna()][0:idx]
df_n_fe  = df1[df1['nfe_gspspec'].notna()][0:idx]
df_cr_fe = df1[df1['crfe_gspspec'].notna()][0:idx]
df_ce_fe = df1[df1['cefe_gspspec'].notna()][0:idx]
df_ni_fe = df1[df1['nife_gspspec'].notna()][0:idx]

# %%
df_A = df1[df1['spectraltype_esphs'] == "A"][0:idx]
df_B = df1[df1['spectraltype_esphs'] == "B"][0:idx]
df_CSTAR = df1[df1['spectraltype_esphs'] == "CSTAR"][0:idx]
df_F = df1[df1['spectraltype_esphs'] == "F"][0:idx]
df_G = df1[df1['spectraltype_esphs'] == "G"][0:idx]
df_K = df1[df1['spectraltype_esphs'] == "K"][0:idx]
df_M = df1[df1['spectraltype_esphs'] == "M"][0:idx]
df_O = df1[df1['spectraltype_esphs'] == "O"][0:idx]

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

fx = df1[(df1.logg_gspphot > 0) & (df1.logg_gspphot < 10)]

eq = SkyCoord(fx.ra, fx.dec, unit=u.deg)
gal = eq.galactic

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111,projection="aitoff")
image = ax.scatter(gal.l.wrap_at('180d').radian, gal.b.radian, c=fx.logg_gspphot, cmap="jet", marker='.')
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label("LogG",size=15)
plt.title("Gaia DR3 Star LogG [" + str(fx.shape[0]) + "[\n", fontsize=16)
plt.grid()
fig.show()

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

fx = df1[(df1.age_flame > 0) & (df1.age_flame < 14)]

eq = SkyCoord(fx.ra, fx.dec, unit=u.deg)
gal = eq.galactic

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111,projection="aitoff")
image = ax.scatter(gal.l.wrap_at('180d').radian, gal.b.radian, c=fx.age_flame, cmap="jet", marker='.')
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label("Age",size=15)
plt.title("Gaia DR3 Star Age [" + str(fx.shape[0]) + "[\n", fontsize=16)
plt.grid()
fig.show()

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

fx = df1[(df1['Star_Type'] == "subgiants") & (df1['mh_gspphot'] < 0)]
#fx = df1[df1['Star_Type'] == "red_giants"]

eq = SkyCoord(fx.ra, fx.dec, unit=u.deg)
gal = eq.galactic

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111,projection="aitoff")
image = ax.scatter(gal.l.wrap_at('180d').radian, gal.b.radian, c=fx.mh_gspphot, cmap="jet_r", marker='.')
bar = fig.colorbar(image,orientation="vertical",pad=0.01)
bar.set_label("Metallicity M/H",size=15)
plt.title("Gaia DR3 Star Metallicity M/H [" + str(fx.shape[0]) + "[\n", fontsize=16)
plt.grid()
fig.show()

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(111)
"""image1 = plt.scatter(df_A['l'], df_A['b'], label="Class A " + str(df_A.shape[0]), marker='.', linewidth=0,
            c='orange',edgecolor='k',cmap="jet_r")""";
image2 = plt.scatter(df_B['l'], df_B['b'], label="Class B " + str(df_B.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
"""image3 = plt.scatter(df_F['l'], df_F['b'], label="Class F " + str(df_F.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image4 = plt.scatter(df_G['l'], df_G['b'], label="Class G " + str(df_G.shape[0]), marker='.', linewidth=0,
            c='red',edgecolor='k',cmap="jet_r")
image5 = plt.scatter(df_K['l'], df_K['b'], label="Class K " + str(df_K.shape[0]), marker='.', linewidth=0,
            c='violet',edgecolor='k',cmap="jet_r")
image6 = plt.scatter(df_M['l'], df_M['b'], label="Class M " + str(df_M.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")""";
image7 = plt.scatter(df_O['l'], df_O['b'], label="Class O " + str(df_O.shape[0]), marker='.', linewidth=0,
            c='red',edgecolor='k',cmap="jet_r")

ax = plt.gca()
#plt.gca().invert_yaxis()
plt.xlabel('l', fontsize=15)
plt.ylabel('b', fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.title('Gaia DR3', fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(111)
"""image1 = plt.scatter(df_A['ra'], df_A['dec'], label="Class A " + str(df_A.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")""";
image2 = plt.scatter(df_B['ra'], df_B['dec'], label="Class B " + str(df_B.shape[0]), marker='.', linewidth=0,
            c='blue',edgecolor='k',cmap="jet_r")
"""image3 = plt.scatter(df_F['ra'], df_F['dec'], label="Class F " + str(df_F.shape[0]), marker='.', linewidth=0,
            c='green',edgecolor='k',cmap="jet_r")
image4 = plt.scatter(df_G['ra'], df_G['dec'], label="Class G " + str(df_G.shape[0]), marker='.', linewidth=0,
            c='red',edgecolor='k',cmap="jet_r")
image5 = plt.scatter(df_K['ra'], df_K['dec'], label="Class K " + str(df_K.shape[0]), marker='.', linewidth=0,
            c='violet',edgecolor='k',cmap="jet_r")
image6 = plt.scatter(df_M['ra'], df_M['dec'], label="Class M " + str(df_M.shape[0]), marker='.', linewidth=0,
            c='aqua',edgecolor='k',cmap="jet_r")""";
image7 = plt.scatter(df_O['ra'], df_O['dec'], label="Class O " + str(df_O.shape[0]), marker='.', linewidth=0,
            c='red',edgecolor='k',cmap="jet_r")

ax = plt.gca()
#plt.gca().invert_yaxis()
plt.xlabel('Ra', fontsize=15)
plt.ylabel('Dec', fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.title('Gaia DR3', fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
r1 = df_all

r1.drop_duplicates()
r1.shape[0]

# %%
print("\n< Not Null >\n")

print("Alpha/Fe: " +str(r1[r1['alphafe_gspspec'].notna()].shape[0]))
print("Fe/M: " +str(r1[r1['fem_gspspec'].notna()].shape[0]))
print("Si/Fe: " +str(r1[r1['sife_gspspec'].notna()].shape[0]))
print("Ca/Fe: " +str(r1[r1['cafe_gspspec'].notna()].shape[0]))
print("Ti/Fe: " +str(r1[r1['tife_gspspec'].notna()].shape[0]))
print("Mg/Fe: " +str(r1[r1['mgfe_gspspec'].notna()].shape[0]))
print("Nd/Fe: " +str(r1[r1['ndfe_gspspec'].notna()].shape[0]))
print("FeII/M: " +str(r1[r1['feiim_gspspec'].notna()].shape[0]))
print("S/Fe: " +str(r1[r1['sfe_gspspec'].notna()].shape[0]))
print("Zr/Fe: " +str(r1[r1['zrfe_gspspec'].notna()].shape[0]))
print("N/Fe:  " +str(r1[r1['nfe_gspspec'].notna()].shape[0]))
print("Cr/Fe: " +str(r1[r1['crfe_gspspec'].notna()].shape[0]))
print("Ce/Fe: " +str(r1[r1['cefe_gspspec'].notna()].shape[0]))
print("Ni/Fe: " +str(r1[r1['nife_gspspec'].notna()].shape[0]))

# %%
r1.columns.sort_values().tolist()

# %%
target1 = ""

# %%
def AbundanceCategories(x1):
    main_sequence = x1[x1['logg_gspphot'].astype(float) > 4.20]
    turnoff       = x1[(x1['logg_gspphot'].astype(float) < 4.20) & (x1['logg_gspphot'].astype(float) > 3.90)]
    subgiants     = x1[(x1['logg_gspphot'].astype(float) < 3.90) & (x1['logg_gspphot'].astype(float) > 3.60)]
    red_giants    = x1[x1['logg_gspphot'].astype(float) < 3.60]
    
    print("main_sequence: " + str(main_sequence.shape[0]))
    print("turnoff: " + str(turnoff.shape[0]))
    print("subgiants: " + str(subgiants.shape[0]))
    print("red_giants: " + str(red_giants.shape[0]))

# %%
def plot00(r1):
    fdwarf = r1[r1['logg_gspphot'].astype(float) > 3.7]
    fmain_sequence = r1[r1['logg_gspphot'].astype(float) > 4.20]
    fturnoff       = r1[(r1['logg_gspphot'].astype(float) < 4.20) & (r1['logg_gspphot'].astype(float) > 3.90)]
    fsubgiants     = r1[(r1['logg_gspphot'].astype(float) < 3.90) & (r1['logg_gspphot'].astype(float) > 3.60)]
    fred_clump     = r1[(r1['logg_gspphot'].astype(float) < 2.55) & (r1['logg_gspphot'].astype(float) > 2.35)]
    fred_giants    = r1[r1['logg_gspphot'].astype(float) < 3.60]

    print("Field: " + str(target1))
    print("Stars: " + str(r1.shape[0]))
    print("\nmain_sequence: " + str(fmain_sequence.shape[0]))
    print("turnoff: " + str(fturnoff.shape[0]))
    print("subgiants: " + str(fsubgiants.shape[0]))
    print("red_clump: " + str(fred_clump.shape[0]))
    print("\nred_giants: " + str(fred_giants.shape[0] - fred_clump.shape[0]))
    print("dwarfs: " + str(fdwarf.shape[0]))

    print("\nAbundanceCategories:")
    AbundanceCategories(r1)

    print('\nSpectraltype: ' + str(sp.unique(r1['spectraltype_esphs'])))

    unique_spectraltype = sp.unique(r1['spectraltype_esphs'])

    for i in unique_spectraltype:
        print(str(i) + ": " + str(r1[r1['spectraltype_esphs'] == i].shape[0]))

# %%
def plot00A(r1):
    ## Checking for null values
    print(target1)
    print("\nNumber of stars: " + str(r1.shape[0]) + "\n")

    print("Sum of Null Values")

    print(pd.isnull(r1).sum())

# %%
def plot00B():
    ## Checking for not null values
    print(target1)
    print("\nNumber of stars: " + str(r1.shape[0]) + "\n")

    print("Sum of Not Null Values")

    print(pd.notnull(r1).sum())

# %%
def plot01(R_sun_limit):

    #R_sun_limit = 25000

    import matplotlib.pyplot as plt
    import seaborn as sns
    sns.set()

    rr0 = r1[r1.radius_gspphot> 0]
    rr1 = r1[r1.radius_gspphot < R_sun_limit]

    plt.style.use('dark_background')
    sns.relplot(x='bp_rp', y='mg_gspphot', height=8.5, aspect=1.2, legend=None, s=15, 
                hue='bp_rp',
                palette='RdYlBu_r',
                #size='radius_gspphot',
                #sizes=(1,rr1['radius_gspphot'].max()/rr1['radius_gspphot'].min()),
                data=rr1
                )
    plt.ylim(rr1['mg_gspphot'].max()+1, rr1['mg_gspphot'].min()-1)
    plt.xlabel('Color (bp - rp)', fontsize = 17)
    plt.ylabel('Absolute Magnitude', fontsize = 17)
    plt.title('Hertzsprung-Russel Diagram of ' + str(target1) + '\nNumber of Stars: ' + str(rr1.shape[0]), 
            fontsize = 17)

    plt.show()

# %%
def plot01B(r1):
    fdwarf = r1[r1['logg_gspphot'].astype(float) > 3.7]
    fmain_sequence = r1[r1['logg_gspphot'].astype(float) > 4.20]
    fturnoff       = r1[(r1['logg_gspphot'].astype(float) < 4.20) & (r1['logg_gspphot'].astype(float) > 3.90)]
    fsubgiants     = r1[(r1['logg_gspphot'].astype(float) < 3.90) & (r1['logg_gspphot'].astype(float) > 3.60)]
    fred_clump     = r1[(r1['logg_gspphot'].astype(float) < 2.55) & (r1['logg_gspphot'].astype(float) > 2.35)]
    fred_giants    = r1[r1['logg_gspphot'].astype(float) < 3.60]
    
    plt.style.use('dark_background')
    s1Label = "TEFF"
    fig = plt.figure(figsize=(10, 8))
    plt.subplot(111)
    #plt.scatter(fmain_sequence['bp_rp'], fmain_sequence['mg_gspphot'], label=('Main_sequence stars: ' + str(fmain_sequence.shape[0])), marker='o', linewidth=0,s=15,c='yellow')
    plt.scatter(fdwarf['bp_rp'], fdwarf['mg_gspphot'], label=('Dwarf stars: ' + str(fdwarf.shape[0])), marker='o', linewidth=0,s=15,c='yellow')
    plt.scatter(fturnoff['bp_rp'], fturnoff['mg_gspphot'], label=('Turnoff stars: ' + str(fturnoff.shape[0])), marker='o', linewidth=0,s=15,c='violet')
    plt.scatter(fsubgiants['bp_rp'], fsubgiants['mg_gspphot'], label=('Subgiants stars: ' + str(fsubgiants.shape[0])), marker='o', linewidth=0,s=15,c='g')
    plt.scatter(fred_clump ['bp_rp'], fred_clump ['mg_gspphot'], label=('Red Clump stars: ' + str(fred_clump .shape[0])), marker='o', linewidth=0,s=25,c='orange')
    plt.scatter(fred_giants['bp_rp'], fred_giants['mg_gspphot'], label=('Red Giant stars: ' + str(fred_giants.shape[0])), marker='o', linewidth=0,s=20,c='r')
    ax = plt.gca()
    plt.gca().invert_yaxis()
    plt.xlabel('BP_RP', fontsize=15)
    plt.ylabel('Absolute Magnitude', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    plt.legend(fontsize=15)
    plt.title('Hertzsprung-Russel Diagram', fontsize=15)
    plt.show()

# %%
def plot02(R_sun_limit):

    #R_sun_limit = 25000


    rr0 = r1[r1.radius_gspphot > 0]
    rr1 = r1[r1.radius_gspphot < R_sun_limit]
    rr2 = rr1[rr1.parallax_over_error > 10]

    plt.style.use('dark_background')
    sns.relplot(x='bp_rp', y='mg_gspphot', 
                height=8.5, 
                aspect=1.2, 
                legend=None,
                hue='bp_rp',
                palette='RdYlBu_r',
                size='radius_gspphot',
                sizes=(1,rr2['radius_gspphot'].max()/rr2['radius_gspphot'].min()),
                data=rr2
                )
    plt.ylim(rr2['mg_gspphot'].max()+1, rr2['mg_gspphot'].min()-1)
    plt.xlabel('Color (bp - rp)', fontsize = 17)
    plt.ylabel('Absolute Magnitude', fontsize = 17)
    plt.title('Hertzsprung-Russel Diagram of ' + 
            str(target1) + "\nparallax_over_error > 10"
            + '\nNumber of Stars: ' + 
            str(rr2.shape[0]), 
            fontsize = 17)

    plt.show()

# %%
def plot03():
    s1Label = "TEFF"
    fig = plt.figure(figsize=(10, 8))
    plt.subplot(111)
    plt.scatter(r1['teff_gspphot'], r1['logg_gspphot'], marker='o', linewidth=0,s=15,
                c=r1.logg_gspphot,edgecolor='k',cmap="jet_r")
    ax = plt.gca()
    plt.gca().invert_xaxis()
    plt.gca().invert_yaxis()
    plt.xlabel('Teff', fontsize=15)
    plt.ylabel('LogG', fontsize=15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.grid()
    #plt.legend(fontsize=15)
    plt.title(str(target1) + '\nHertzsprung-Russel Diagram'  + '\nNumber of Stars: ' + str(r1.shape[0]), fontsize=15)
    plt.xlim([20000,3000])
    plt.grid()
    plt.show()

# %%
def plotly_plots(r1, x1, target1, title1):
    #fig1 = px.histogram(r1, x=x1, title=str(target1)+": " + str(title1))
    #fig1.show();

    fig2 = px.scatter(r1, x='bp_rp', y='mg_gspphot', hover_data=[x1,'source_id','ra','dec','teff_gspphot','logg_gspphot','mh_gspphot',
                     'distance_gspphot','radius_gspphot','spectraltype_esphs', 'SpT2', 'SpT2_dereddened',
                     'lum_flame','mass_flame', 'age_flame', 'evolstage_flame','evolstage_type' ,'Star_Type', 'bp_rp', 'ebpminrp_gspphot'], 
    color=x1, color_continuous_scale='rdylbu', #opacity=0.5,
    title=str(target1)+": " + str(title1))
    #fig2['layout']['xaxis']['autorange']= "reversed"
    fig2['layout']['yaxis']['autorange']= "reversed"
    fig2.update_traces(marker={'size': 6})
    fig2.show()

# %%
def plotly_plots_reverse(r1, x1, target1, title1):
    #fig1 = px.histogram(r1, x=x1, title=str(target1)+": " + str(title1))
    #fig1.show();

    fig2 = px.scatter(r1, x='bp_rp', y='mg_gspphot', hover_data=[x1,'source_id','ra','dec','teff_gspphot','logg_gspphot','mh_gspphot',
                     'distance_gspphot','radius_gspphot','spectraltype_esphs', 'SpT2', 'SpT2_dereddened',
                     'lum_flame','mass_flame', 'age_flame', 'evolstage_flame','evolstage_type' ,'Star_Type', 'bp_rp', 'ebpminrp_gspphot'], 
    color=x1, color_continuous_scale='jet', #opacity=0.5,
    title=str(target1)+": " + str(title1))
    #fig2['layout']['xaxis']['autorange']= "reversed"
    fig2['layout']['yaxis']['autorange']= "reversed"
    fig2.update_traces(marker={'size': 5})
    fig2.show()

# %%
def plotly_plots2(r1, x1, target1, title1):
    #fig1 = px.histogram(r1, x=x1, title=str(target1)+": " + str(title1))
    #fig1.show();

    #r1['bp_rp_dereddened'] = []
    r1['bp_rp_dereddened'] = r1['bp_rp'] - r1['ebpminrp_gspphot']

    fig2 = px.scatter(r1, x='bp_rp_dereddened', y='mg_gspphot', hover_data=[x1,'source_id','ra','dec','teff_gspphot','logg_gspphot','mh_gspphot',
                     'distance_gspphot','radius_gspphot','spectraltype_esphs', 'SpT2', 'SpT2_dereddened',
                     'lum_flame','mass_flame', 'age_flame', 'evolstage_flame','evolstage_type' ,'Star_Type', 'bp_rp', 'ebpminrp_gspphot'], 
    color=x1, color_continuous_scale='rdylbu',
    title=str(target1)+": " + str(title1))
    #fig2['layout']['xaxis']['autorange']= "reversed"
    fig2['layout']['yaxis']['autorange']= "reversed"
    fig2.show()

# %%
# https://www.pas.rochester.edu/~emamajek/EEM_dwarf_UBVIJHK_colors_Teff.txt

unique_SpT2  = sp.unique(r1['SpT2'])

print("Star subclass based on BP_RP color\n")

for i in unique_SpT2 :
    print(str(i) + ": " + str(r1[r1['SpT2'] == i].shape[0]))

# %%
# https://www.pas.rochester.edu/~emamajek/EEM_dwarf_UBVIJHK_colors_Teff.txt

unique_SpT2_dereddened  = sp.unique(r1['SpT2_dereddened'])

print("Star subclass based on BP_RP color minus reddening (ebpminrp_gspphot)\n")

for i in unique_SpT2_dereddened :
    print(str(i) + ": " + str(r1[r1['SpT2_dereddened'] == i].shape[0]))

# %%
target1 = ""

Plot_00_flag  = "Y"       # Plot "Stats"
Plot_00A_flag = "N"       # Checking for null values
Plot_00B_flag = "N"       # Checking for not null values

Plot_01_flag  = "Y"       # Plot "BP_RP versus Absolute Magnitude"
Plot_02_flag  = "N"       # Plot "BP_RP versus Absolute Magnitude - parallax_over_error >10"
Plot_03_flag  = "Y"       # Plot "Teff versus LogG"

Plot_10_flag  = "NN"       # Plot "Color = teff_gspphot - BP_RP versus Absolute Magnitude"
Plot_11_flag  = "Y"       # Plot "Color = logg_gspphot - BP_RP versus Absolute Magnitude"
Plot_12_flag  = "Y"       # Plot "Color = mh_gspphot - BP_RP versus Absolute Magnitude"
Plot_13_flag  = "Y"       # Plot "Color = distance_gspphot - BP_RP versus Absolute Magnitude"

Plot_14_flag  = "NN"       # Plot "Color = ag_gspphot - BP_RP versus Absolute Magnitude"
Plot_15_flag  = "NN"       # Plot "Color = abp_gspphot - BP_RP versus Absolute Magnitude"

Plot_16_flag  = "Y"       # Plot "Color = radius_gspphot - BP_RP versus Absolute Magnitude"
Plot_17_flag  = "Y"       # Plot "Color = lum_flame - BP_RP versus Absolute Magnitude"
Plot_18_flag  = "Y"       # Plot "Color = mass_flame - BP_RP versus Absolute Magnitude"
Plot_19_flag  = "Y"       # Plot "Color = age_flame - BP_RP versus Absolute Magnitude"


Plot_029_flag  = "Y"      # Plot "Abundance of alpha-elements [alpha/Fe]"
Plot_029B_flag  = "N"     # Plot "Abundance of alpha-elements [alpha/Fe] dereddened"

Plot_030_flag  = "N"      # Plot "Abundance of neutral iron [Fe/M"
Plot_031_flag  = "N"      # Plot "Abundance of Silicon [Si/Fe]"
Plot_032_flag  = "N"      # Plot "Abundance of Calcium [Ca/Fe]"
Plot_033_flag  = "N"      # Plot "Abundance of Titanium [Ti/Fe]"       

Plot_034_flag  = "N"      # Plot "Abundance of Magnesium [Mg/Fe]"

Plot_035_flag  = "N"      # Plot "Abundance of neodymium [Nd/Fe]"
Plot_036_flag  = "N"      # Plot "Abundance of ionised iron [FeII/M]"

Plot_037_flag  = "N"      # Plot "Abundance of Sulphur [S/Fe]"

Plot_038_flag  = "N"      # Plot "Abundance of Zirconium [Zr/Fe]"
Plot_039_flag  = "N"      # Plot "Abundance of Nitrogen [N/Fe]]"
Plot_040_flag  = "N"      # Plot "Abundance of Chromium [Cr/Fe]"
Plot_041_flag  = "N"      # Plot "Abundance of Cerium [Ce/Fe]"
Plot_042_flag  = "N"      # Plot "Abundance of Nickel [Ni/Fe]"

# %% [markdown]
# ## Change idx to fit plots

# %%
r1 = df_all[0:2000]

# %%
pd.options.display.max_columns = None
pd.set_option('display.max_rows', 2000)

if Plot_00_flag == "Y":
    plot00(r1)

if Plot_00A_flag == "Y":
    plot00A(r1)

if Plot_00B_flag == "Y":
    plot00B()

if Plot_01_flag == "Y":
    plot01(2500)
    plot01B(r1)

if Plot_02_flag == "Y":
    plot02(2500)

if Plot_03_flag == "Y":
    plot03()




if Plot_10_flag == "Y":
    plotly_plots(r1, 'teff_gspphot', target1, "Color = teff_gspphot - Effective Temperature")

if Plot_11_flag == "Y":
    plotly_plots(r1, 'logg_gspphot', target1, "Color = logg_gspphot - Surface Gravity")

if Plot_12_flag == "Y":
    plotly_plots(r1, 'mh_gspphot', target1, "Color = mh_gspphot - Iron Abundance")

if Plot_13_flag == "Y":
    plotly_plots_reverse(r1, 'distance_gspphot', target1, "Color = distance_gspphot - Distance (1pc - 100kpc")

if Plot_14_flag == "Y":
    plotly_plots(r1, 'ag_gspphot', target1, "Color = ag_gspphot - Extinction in G band")

if Plot_15_flag == "Y":
    plotly_plots(r1, 'abp_gspphot', target1, "Color = abp_gspphot - Broadband Extinction in Gbp band")

if Plot_16_flag == "Y":
    plotly_plots_reverse(r1, 'radius_gspphot', target1, "Color = radius_gspphot - Radius")

if Plot_17_flag == "Y":
    plotly_plots_reverse(r1, 'lum_flame', target1, "Color = lum_flame - Luminosity")

if Plot_18_flag == "Y":
    plotly_plots_reverse(r1, 'mass_flame', target1, "Color = mass_flame - Mass")

if Plot_19_flag == "Y":
    plotly_plots_reverse(r1, 'age_flame', target1, "Color = age_flame - Age")



if Plot_029_flag == "Y":
        #plotly_plots(r1, 'alphafe_gspspec', target1, "Abundance of alpha-elements [alpha/Fe]")
        plotly_plots(df_alpha_fe, 'alphafe_gspspec', target1, "Abundance of alpha-elements [alpha/Fe]  Stars: " + str(df_alpha_fe.shape[0]))

if Plot_029B_flag == "Y":
        #plotly_plots2(r1, 'alphafe_gspspec', target1, "Abundance of alpha-elements [alpha/Fe]")
        plotly_plots2(df_alpha_fe, 'alphafe_gspspec', target1, "Abundance of alpha-elements [alpha/Fe]  Stars: " + str(df_alpha_fe.shape[0]))

if Plot_030_flag == "Y":
        #plotly_plots(r1, 'fem_gspspec', target1, "Abundance of neutral iron [Fe/M")
        plotly_plots(df_fe_m, 'fem_gspspec', target1, "Abundance of neutral iron [Fe/M]]  Stars: " + str(df_fe_m.shape[0]))

if Plot_031_flag == "Y":
    #plotly_plots(r1, 'sife_gspspec', target1, "Abundance of Silicon [Si/Fe]")
    plotly_plots(df_si_fe, 'sife_gspspec', target1, "Abundance of Silicon [Si/Fe]  Stars: " + str(df_si_fe.shape[0]))

if Plot_032_flag == "Y":
    #plotly_plots(r1, 'cafe_gspspec', target1, "Abundance of Calcium [Ca/Fe]")
    plotly_plots(df_ca_fe, 'cafe_gspspec', target1, "Abundance of Calcium [Ca/Fe]  Stars: " + str(df_ca_fe.shape[0]))

if Plot_033_flag == "Y":
    #plotly_plots(r1, 'tife_gspspec', target1, "Abundance of Titanium [Ti/Fe]")
    plotly_plots(df_ti_fe, 'tife_gspspec', target1, "Abundance of Titanium [Ti/Fe]  Stars: " + str(df_ti_fe.shape[0]))

if Plot_034_flag == "Y":
    #plotly_plots(r1, 'mgfe_gspspec', target1, "Abundance of Magnesium [Mg/Fe]")
    plotly_plots(df_mg_fe, 'mgfe_gspspec', target1, "Abundance of Magnesium [Mg/Fe]  Stars: " + str(df_mg_fe.shape[0]))

if Plot_035_flag == "Y":
    #plotly_plots(r1, 'ndfe_gspspec', target1, "Abundance of Neodymium [Nd/Fe]")
    plotly_plots(df_nd_fe, 'ndfe_gspspec', target1, "Abundance of Neodymium [Nd/Fe]  Stars: " + str(df_nd_fe.shape[0]))

if Plot_036_flag == "Y":
    #plotly_plots(r1, 'feiim_gspspec', target1, "Abundance of ionised iron [FeII/M]")
    plotly_plots(df_feii_m, 'feiim_gspspec', target1, "Abundance of ionised iron [FeII/M]  Stars: " + str(df_feii_m.shape[0]))

if Plot_037_flag == "Y":
    #plotly_plots(r1, 'sfe_gspspec', target1, "Abundance of Sulphur [S/Fe]")
    plotly_plots(df_s_fe, 'sfe_gspspec', target1, "Abundance of Sulphur [S/Fe]  Stars: " + str(df_s_fe.shape[0]))

if Plot_038_flag == "Y":
    #plotly_plots(r1, 'zrfe_gspspec', target1, "Abundance of Zirconium [Zr/Fe]  Stars: " + str(df_zr_fe.shape[0]))
    plotly_plots(df_zr_fe, 'zrfe_gspspec', target1, "Abundance of Zirconium [Zr/Fe]  Stars: " + str(df_zr_fe.shape[0]))

if Plot_039_flag == "Y":
    #plotly_plots(r1, 'nfe_gspspec', target1, "Abundance of Nitrogen [N/Fe]]")
    plotly_plots(df_n_fe, 'nfe_gspspec', target1, "Abundance of Nitrogen [N/Fe]  Stars: " + str(df_n_fe.shape[0]))

if Plot_040_flag == "Y":
    #plotly_plots(r1, 'crfe_gspspec', target1, "Abundance of Chromium [Cr/Fe]")
    plotly_plots(df_cr_fe, 'crfe_gspspec', target1, "Abundance of Chromium [Cr/Fe]  Stars: " + str(df_cr_fe.shape[0]))

if Plot_041_flag == "Y":
   #plotly_plots(r1, 'cefe_gspspec', target1, "Abundance of Cerium [Ce/Fe]")
   plotly_plots(df_ce_fe, 'cefe_gspspec', target1, "Abundance of Cerium [Ce/Fe]  Stars: " + str(df_ce_fe.shape[0]))

if Plot_042_flag == "Y":
    #plotly_plots(r1, 'nife_gspspec', target1, "Abundance of Nickel [Ni/Fe]")
    plotly_plots(df_ni_fe, 'nife_gspspec', target1, "Abundance of Nickel [Ni/Fe]  Stars: " + str(df_ni_fe.shape[0]))

print("\nDone!")

# %%
import seaborn as sns

df = r1[r1['distance_gspphot'] < 10000]
sns.histplot(data=df, x='distance_gspphot', bins=20);

# %%
r1.shape[0]

# %%
df_OB = df_all[(df_all['spectraltype_esphs'] == "O") | (df_all['spectraltype_esphs'] == "B")] 
print("df_OB: " + str(df_OB.shape[0]))

# %%
# Class O star counts

df_OB_O = df_OB[df_OB['spectraltype_esphs'] == "O"]
print("Class O: " + str(df_OB_O.shape[0]))

# %%
# Class O star distance (pc)

import seaborn as sns

sns.histplot(data=df_OB_O, x='distance_gspphot', bins=20);

# %%
# Class B star counts

df_OB_B = df_OB[df_OB['spectraltype_esphs'] == "B"]
print("Class B: " + str(df_OB_B.shape[0]))

# %%
# Class B star distance (pc)

sns.histplot(data=df_OB_B, x='distance_gspphot', bins=20);

# %%
# Class OB star counts

print("Class OB: " + str(df_OB.shape[0]))

# %%
# Class OB star distance (pc)

sns.histplot(data=df_OB, x='distance_gspphot', bins=20);

# %%
import plotly.express as px

plotly_plots(df_OB_O, 'logg_gspphot',"Class O Stars " + str(df_OB_O.shape[0]), "Surface Gravity [logg_gspphot]")
plotly_plots(df_OB_B, 'logg_gspphot',"Class B Stars " + str(df_OB_B.shape[0]), "Surface Gravity [logg_gspphot]")

# %%
plotly_plots(df_OB_O, 'mh_gspphot',"Class O Stars " + str(df_OB_O.shape[0]), "Iron Abundance [mh_gspphot]")
plotly_plots(df_OB_B, 'mh_gspphot',"Class B Stars " + str(df_OB_B.shape[0]), "Iron Abundance [mh_gspphot]")

# %%
plotly_plots_reverse(df_OB_O, 'distance_gspphot',"Class O Stars " + str(df_OB_O.shape[0]), "Distance (pc) [distance_gspphot]")
sns.histplot(data=df_OB_O, x='distance_gspphot', bins=20);

# %%
plotly_plots_reverse(df_OB_B, 'distance_gspphot',"Class B Stars " + str(df_OB_B.shape[0]), "Distance (pc) [distance_gspphot]")
sns.histplot(data=df_OB_B, x='distance_gspphot', bins=20);

# %%
import matplotlib.pyplot as plt

sns.set()

plt.style.library['seaborn']


df = df_OB_O[df_OB_O['distance_gspphot'] < 1500]
df2 = df_OB_O[df_OB_O['distance_gspphot'] >= 1500]

fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="ra", y="dec", fill=True, color="r");
plt.title('Gaia DR3 Class O - Distance < 1500 pc' + ": " + str(df.shape[0]), fontsize=15);

"""fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="pmra", y="pmdec", fill=True, color="b", label="Distance < 1500 pc");
sns.kdeplot(
    data=df2, x="pmra", y="pmdec", fill=True, color="r", label="Distance >= 1500 pc");
plt.title('Gaia DR3 Class O - Distance < 1500 pc' + ": " + str(df.shape[0]), fontsize=15);
plt.legend()
ax = plt.gca()
#leg = ax.get_legend()
leg = ax.legend()
leg.legendHandles[0].set_color('red')
leg.legendHandles[1].set_color('blue')
ax.legend(loc='best')""";

"""fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="pmra", y="pmdec", fill=True, color="r", label="Distance < 1500 pc");
plt.title('Gaia DR3 Class O - Distance < 1500 pc' + ": " + str(df.shape[0]), fontsize=15);""";

plotly_plots(df, 'mh_gspphot',"Class O - Distance < 1500 pc " + str(df.shape[0]), "Iron Abundance [mh_gspphot]")




df = df_OB_O[df_OB_O['distance_gspphot'] >= 1500]

fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="ra", y="dec", fill=True, color="r");
plt.title('Gaia DR3 Class O - Distance >= 1500 pc' + ": " + str(df.shape[0]), fontsize=15);

"""fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="pmra", y="pmdec", fill=True, color="r");
plt.title('Gaia DR3 Class O - Distance >= 1500 pc' + ": " + str(df.shape[0]), fontsize=15);""";

plotly_plots(df, 'mh_gspphot',"Class O - Distance >= 1500 pc " + str(df.shape[0]), "Iron Abundance [mh_gspphot]")

# %%
df = df_OB_B[df_OB_B['distance_gspphot'] < 1500]
fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="ra", y="dec", fill=True, color="b");
plt.title('Class B - Distance < 1500 pc' + ": " + str(df.shape[0]), fontsize=15);
plotly_plots(df, 'mh_gspphot',"Gaia DR3 Class B - Distance < 1500 pc " + str(df.shape[0]), "Iron Abundance [mh_gspphot]")

"""fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="pmra", y="pmdec", fill=True, color="r", label="Distance < 1500 pc");
plt.title('Gaia DR3 Class B - Distance < 1500 pc' + ": " + str(df.shape[0]), fontsize=15);""";


df = df_OB_B[df_OB_B['distance_gspphot'] >= 1500]
fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="ra", y="dec", fill=True, color="b");
plt.title('Class B - Distance >= 1500 pc' + ": " + str(df.shape[0]), fontsize=15);
plotly_plots(df, 'mh_gspphot',"Gaia DR3 Class B - Distance >= 1500 pc " + str(df.shape[0]), "Iron Abundance [mh_gspphot]")

"""fig = plt.figure(figsize=(10, 6))
sns.kdeplot(
    data=df, x="pmra", y="pmdec", fill=True, color="r", label="Distance >= 1500 pc");
plt.title('Gaia DR3 Class B - Distance >= 1500 pc' + ": " + str(df.shape[0]), fontsize=15);""";

# %%
# %%html
# <div styles="text-align:center;">
# <iframe src="https://gea.esac.esa.int/archive/" width="960" height="540"></iframe>
# </div>
